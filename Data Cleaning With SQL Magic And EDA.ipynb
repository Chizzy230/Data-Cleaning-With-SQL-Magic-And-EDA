# %% [markdown]
# # Loading SQL

# %%
# %load_ext sql
# %sql postgresql://postgres:252525@localhost/sql_class

# %% [markdown]
# # Seeing the dataset

# %%
# %%sql
# select *
# from pet_supplies
# limit 10
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 10 rows affected.
# [(1, 'Food', 'Bird', 'large', '51.1', 1860.62, '7', 1),
#  (2, 'Housing', 'Bird', 'MEDIUM', '35.98', 963.6, '6', 0),
#  (3, 'Food', 'Dog', 'medium', '31.23', 898.3, '5', 1),
#  (4, 'Medicine', 'Cat', 'small', '24.95', 982.15, '6', 1),
#  (5, 'Housing', 'Cat', 'Small', '26.18', 832.63, '7', 1),
#  (6, 'Housing', 'Dog', 'Small', '30.77', 874.58, '7', 0),
#  (7, 'Housing', 'Dog', 'Small', '31.04', 875.07, '5', 0),
#  (8, 'Toys', 'Cat', 'medium', '28.9', 1074.31, '4', 0),
#  (9, 'Equipment', 'Fish', 'MEDIUM', '17.82', 503.67, '5', 0),
#  (10, 'Medicine', 'Dog', 'medium', '24.93', 838.88, '8', 0)]

# %% [markdown]
# # Cleaning The Dataset

# %% [markdown]
# ## Cleaning the size column

# %%
# %%sql
# update pet_supplies
# set size = lower(size)
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 1500 rows affected.
# []

# %%
# %%sql
# select distinct(size)
# from pet_supplies
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 3 rows affected.
# [('large',), ('medium',), ('small',)]

# %% [markdown]
# ## Cleaning the price column

# %%
# %%sql
# select price
# from pet_supplies
# where price = 'unlisted'
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 150 rows affected.
# [('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',),
#  ('unlisted',)]

# %%
# %%sql
# update pet_supplies
# set price = '0'
# where price = 'unlisted'
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 150 rows affected.
# []

# %% [markdown]
# # Cleaning the rating column

# %%
# %%sql
# select rating
# from pet_supplies
# where rating is null
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 0 rows affected.
# []

# %%
# %%sql
# select rating
# from pet_supplies
# where rating = 'NA'
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 150 rows affected.
# [('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',),
#  ('NA',)]

# %%
# %%sql
# update pet_supplies
# set rating = '0'
# where rating = 'NA'
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 150 rows affected.
# []

# %% [markdown]
# # seeing the dataset

# %%
# %%sql
# select *
# from pet_supplies
# limit 10
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 10 rows affected.
# [(1, 'Food', 'Bird', 'large', '51.1', 1860.62, '7', 1),
#  (3, 'Food', 'Dog', 'medium', '31.23', 898.3, '5', 1),
#  (4, 'Medicine', 'Cat', 'small', '24.95', 982.15, '6', 1),
#  (8, 'Toys', 'Cat', 'medium', '28.9', 1074.31, '4', 0),
#  (10, 'Medicine', 'Dog', 'medium', '24.93', 838.88, '8', 0),
#  (14, 'Food', 'Dog', 'large', '40.8', 1450.5, '6', 1),
#  (15, 'Accessory', 'Bird', 'medium', '33.13', 859.29, '4', 1),
#  (16, 'Accessory', 'Bird', 'large', '43.09', 1418.72, '1', 1),
#  (17, 'Equipment', 'Cat', 'small', '28.29', 1040.51, '5', 1),
#  (18, 'Toys', 'Bird', 'medium', '43.91', 1521.51, '3', 1)]

# %% [markdown]
# # Handling the datatypes

# %% [markdown]
# ## Select column

# %%
# %%sql
# select
# cast(price as float)
# from pet_supplies
# limit 10
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 10 rows affected.
# [(51.1,),
#  (31.23,),
#  (24.95,),
#  (28.9,),
#  (24.93,),
#  (40.8,),
#  (33.13,),
#  (43.09,),
#  (28.29,),
#  (43.91,)]

# %% [markdown]
# ## Rating column

# %%
# %%sql
# select
# cast(rating as int)
# from pet_supplies
# order by product_id
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 1500 rows affected.
# [(7,),
#  (6,),
#  (5,),
#  (6,),
#  (7,),
#  (7,),
#  (5,),
#  (4,),
#  (5,),
#  (8,),
#  (7,),
#  (5,),
#  (4,),
#  (6,),
#  (4,),
#  (1,),
#  (5,),
#  (3,),
#  (6,),
#  (7,),
#  (0,),
#  (3,),
#  (3,),
#  (4,),
#  (3,),
#  (4,),
#  (4,),
#  (5,),
#  (7,),
#  (5,),
#  (3,),
#  (7,),
#  (6,),
#  (5,),
#  (6,),
#  (4,),
#  (7,),
#  (2,),
#  (6,),
#  (5,),
#  (3,),
#  (7,),
#  (5,),
#  (3,),
#  (0,),
#  (5,),
#  (0,),
#  (8,),
#  (6,),
#  (6,),
#  (6,),
#  (7,),
#  (7,),
#  (4,),
#  (5,),
#  (6,),
#  (6,),
#  (3,),
#  (6,),
#  (3,),
#  (4,),
#  (3,),
#  (5,),
#  (3,),
#  (5,),
#  (4,),
#  (5,),
#  (3,),
#  (6,),
#  (6,),
#  (0,),
#  (6,),
#  (4,),
#  (0,),
#  (6,),
#  (6,),
#  (3,),
#  (6,),
#  (6,),
#  (3,),
#  (6,),
#  (2,),
#  (5,),
#  (7,),
#  (0,),
#  (6,),
#  (5,),
#  (4,),
#  (4,),
#  (0,),
#  (6,),
#  (6,),
#  (4,),
#  (5,),
#  (0,),
#  (7,),
#  (5,),
#  (6,),
#  (5,),
#  (6,),
#  (0,),
#  (3,),
#  (4,),
#  (6,),
#  (2,),
#  (3,),
#  (8,),
#  (6,),
#  (5,),
#  (4,),
#  (0,),
#  (6,),
#  (6,),
#  (8,),
#  (6,),
#  (3,),
#  (0,),
#  (6,),
#  (4,),
#  (6,),
#  (0,),
#  (3,),
#  (4,),
#  (2,),
#  (5,),
#  (6,),
#  (8,),
#  (0,),
#  (7,),
#  (4,),
#  (4,),
#  (0,),
#  (0,),
#  (0,),
#  (0,),
#  (0,),
#  (5,),
#  (4,),
#  (5,),
#  (6,),
#  (0,),
#  (5,),
#  (6,),
#  (3,),
#  (8,),
#  (8,),
#  (2,),
#  (7,),
#  (5,),
#  (6,),
#  (5,),
#  (4,),
#  (5,),
#  (4,),
#  (5,),
#  (7,),
#  (6,),
#  (3,),
#  (0,),
#  (5,),
#  (3,),
#  (5,),
#  (6,),
#  (6,),
#  (6,),
#  (4,),
#  (6,),
#  (6,),
#  (5,),
#  (3,),
#  (4,),
#  (8,),
#  (5,),
#  (5,),
#  (6,),
#  (4,),
#  (5,),
#  (8,),
#  (5,),
#  (5,),
#  (3,),
#  (7,),
#  (3,),
#  (4,),
#  (6,),
#  (5,),
#  (0,),
#  (5,),
#  (3,),
#  (6,),
#  (3,),
#  (8,),
#  (3,),
#  (0,),
#  (4,),
#  (7,),
#  (6,),
#  (6,),
#  (3,),
#  (2,),
#  (0,),
#  (3,),
#  (2,),
#  (5,),
#  (5,),
#  (4,),
#  (4,),
#  (3,),
#  (5,),
#  (0,),
#  (3,),
#  (0,),
#  (6,),
#  (4,),
#  (4,),
#  (4,),
#  (3,),
#  (3,),
#  (0,),
#  (2,),
#  (5,),
#  (4,),
#  (7,),
#  (5,),
#  (3,),
#  (4,),
#  (4,),
#  (6,),
#  (3,),
#  (5,),
#  (0,),
#  (6,),
#  (6,),
#  (7,),
#  (5,),
#  (0,),
#  (3,),
#  (6,),
#  (5,),
#  (6,),
#  (3,),
#  (7,),
#  (4,),
#  (6,),
#  (4,),
#  (3,),
#  (4,),
#  (2,),
#  (6,),
#  (0,),
#  (6,),
#  (7,),
#  (5,),
#  (3,),
#  (6,),
#  (5,),
#  (0,),
#  (3,),
#  (4,),
#  (5,),
#  (6,),
#  (6,),
#  (4,),
#  (5,),
#  (6,),
#  (0,),
#  (4,),
#  (4,),
#  (5,),
#  (6,),
#  (5,),
#  (6,),
#  (3,),
#  (5,),
#  (3,),
#  (3,),
#  (0,),
#  (4,),
#  (0,),
#  (5,),
#  (3,),
#  (8,),
#  (5,),
#  (4,),
#  (4,),
#  (0,),
#  (0,),
#  (7,),
#  (0,),
#  (8,),
#  (5,),
#  (4,),
#  (6,),
#  (4,),
#  (4,),
#  (4,),
#  (6,),
#  (0,),
#  (6,),
#  (5,),
#  (6,),
#  (6,),
#  (4,),
#  (3,),
#  (5,),
#  (6,),
#  (0,),
#  (3,),
#  (6,),
#  (3,),
#  (5,),
#  (4,),
#  (0,),
#  (6,),
#  (5,),
#  (4,),
#  (5,),
#  (4,),
#  (5,),
#  (0,),
#  (5,),
#  (5,),
#  (4,),
#  (5,),
#  (8,),
#  (4,),
#  (4,),
#  (5,),
#  (0,),
#  (6,),
#  (7,),
#  (6,),
#  (6,),
#  (5,),
#  (6,),
#  (4,),
#  (4,),
#  (3,),
#  (5,),
#  (5,),
#  (5,),
#  (4,),
#  (4,),
#  (6,),
#  (2,),
#  (6,),
#  (0,),
#  (3,),
#  (4,),
#  (6,),
#  (6,),
#  (7,),
#  (3,),
#  (3,),
#  (8,),
#  (4,),
#  (5,),
#  (6,),
#  (5,),
#  (3,),
#  (0,),
#  (7,),
#  (3,),
#  (4,),
#  (5,),
#  (5,),
#  (7,),
#  (5,),
#  (3,),
#  (0,),
#  (6,),
#  (4,),
#  (3,),
#  (5,),
#  (0,),
#  (6,),
#  (4,),
#  (4,),
#  (7,),
#  (4,),
#  (4,),
#  (9,),
#  (2,),
#  (5,),
#  (9,),
#  (4,),
#  (3,),
#  (5,),
#  (6,),
#  (5,),
#  (4,),
#  (6,),
#  (7,),
#  (0,),
#  (0,),
#  (6,),
#  (4,),
#  (5,),
#  (6,),
#  (2,),
#  (7,),
#  (4,),
#  (5,),
#  (4,),
#  (5,),
#  (0,),
#  (6,),
#  (8,),
#  (4,),
#  (5,),
#  (3,),
#  (4,),
#  (3,),
#  (6,),
#  (0,),
#  (3,),
#  (1,),
#  (7,),
#  (6,),
#  (5,),
#  (6,),
#  (7,),
#  (5,),
#  (5,),
#  (6,),
#  (4,),
#  (0,),
#  (5,),
#  (7,),
#  (4,),
#  (6,),
#  (5,),
#  (6,),
#  (6,),
#  (5,),
#  (4,),
#  (9,),
#  (6,),
#  (3,),
#  (4,),
#  (3,),
#  (4,),
#  (5,),
#  (2,),
#  (5,),
#  (5,),
#  (5,),
#  (5,),
#  (8,),
#  (6,),
#  (4,),
#  (4,),
#  (6,),
#  (5,),
#  (3,),
#  (4,),
#  (5,),
#  (9,),
#  (8,),
#  (7,),
#  (6,),
#  (3,),
#  (7,),
#  (3,),
#  (5,),
#  (4,),
#  (8,),
#  (6,),
#  (5,),
#  (4,),
#  (0,),
#  (0,),
#  (6,),
#  (3,),
#  (6,),
#  (2,),
#  (5,),
#  (3,),
#  (4,),
#  (6,),
#  (5,),
#  (0,),
#  (0,),
#  (6,),
#  (5,),
#  (5,),
#  (7,),
#  (3,),
#  (5,),
#  (6,),
#  (4,),
#  (0,),
#  (3,),
#  (4,),
#  (6,),
#  (3,),
#  (6,),
#  (4,),
#  (6,),
#  (5,),
#  (0,),
#  (5,),
#  (4,),
#  (0,),
#  (4,),
#  (6,),
#  (5,),
#  (2,),
#  (3,),
#  (6,),
#  (7,),
#  (6,),
#  (5,),
#  (7,),
#  (4,),
#  (3,),
#  (7,),
#  (7,),
#  (3,),
#  (8,),
#  (9,),
#  (0,),
#  (3,),
#  (6,),
#  (2,),
#  (5,),
#  (6,),
#  (6,),
#  (3,),
#  (8,),
#  (3,),
#  (7,),
#  (8,),
#  (7,),
#  (7,),
#  (6,),
#  (3,),
#  (0,),
#  (0,),
#  (3,),
#  (3,),
#  (5,),
#  (4,),
#  (6,),
#  (1,),
#  (6,),
#  (7,),
#  (3,),
#  (5,),
#  (6,),
#  (7,),
#  (3,),
#  (6,),
#  (5,),
#  (4,),
#  (6,),
#  (7,),
#  (4,),
#  (5,),
#  (5,),
#  (5,),
#  (4,),
#  (5,),
#  (5,),
#  (0,),
#  (0,),
#  (5,),
#  (4,),
#  (5,),
#  (3,),
#  (0,),
#  (7,),
#  (7,),
#  (2,),
#  (5,),
#  (5,),
#  (5,),
#  (0,),
#  (5,),
#  (9,),
#  (7,),
#  (3,),
#  (5,),
#  (5,),
#  (6,),
#  (4,),
#  (1,),
#  (6,),
#  (4,),
#  (4,),
#  (3,),
#  (0,),
#  (4,),
#  (5,),
#  (0,),
#  (5,),
#  (5,),
#  (5,),
#  (5,),
#  (3,),
#  (3,),
#  (0,),
#  (4,),
#  (5,),
#  (6,),
#  (0,),
#  (3,),
#  (5,),
#  (6,),
#  (7,),
#  (6,),
#  (6,),
#  (3,),
#  (1,),
#  (8,),
#  (6,),
#  (2,),
#  (3,),
#  (5,),
#  (0,),
#  (5,),
#  (5,),
#  (4,),
#  (0,),
#  (7,),
#  (5,),
#  (0,),
#  (9,),
#  (4,),
#  (5,),
#  (4,),
#  (6,),
#  (3,),
#  (4,),
#  (4,),
#  (6,),
#  (2,),
#  (4,),
#  (3,),
#  (6,),
#  (4,),
#  (9,),
#  (8,),
#  (4,),
#  (5,),
#  (4,),
#  (7,),
#  (4,),
#  (4,),
#  (6,),
#  (6,),
#  (0,),
#  (8,),
#  (5,),
#  (4,),
#  (6,),
#  (3,),
#  (6,),
#  (3,),
#  (4,),
#  (8,),
#  (3,),
#  (4,),
#  (4,),
#  (0,),
#  (3,),
#  (3,),
#  (3,),
#  (4,),
#  (4,),
#  (1,),
#  (7,),
#  (6,),
#  (7,),
#  (4,),
#  (5,),
#  (8,),
#  (8,),
#  (5,),
#  (6,),
#  (8,),
#  (6,),
#  (5,),
#  (4,),
#  (5,),
#  (4,),
#  (6,),
#  (4,),
#  (4,),
#  (6,),
#  (7,),
#  (0,),
#  (5,),
#  (0,),
#  (6,),
#  (5,),
#  (5,),
#  (4,),
#  (7,),
#  (8,),
#  (9,),
#  (3,),
#  (4,),
#  (0,),
#  (7,),
#  (7,),
#  (5,),
#  (4,),
#  (0,),
#  (3,),
#  (3,),
#  (4,),
#  (4,),
#  (0,),
#  (7,),
#  (7,),
#  (5,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (7,),
#  (7,),
#  (0,),
#  (2,),
#  (4,),
#  (4,),
#  (6,),
#  (5,),
#  (0,),
#  (7,),
#  (5,),
#  (3,),
#  (3,),
#  (6,),
#  (5,),
#  (4,),
#  (0,),
#  (9,),
#  (5,),
#  (4,),
#  (4,),
#  (5,),
#  (0,),
#  (6,),
#  (4,),
#  (4,),
#  (0,),
#  (0,),
#  (2,),
#  (4,),
#  (6,),
#  (7,),
#  (3,),
#  (2,),
#  (4,),
#  (7,),
#  (4,),
#  (4,),
#  (5,),
#  (4,),
#  (9,),
#  (7,),
#  (3,),
#  (6,),
#  (0,),
#  (7,),
#  (6,),
#  (8,),
#  (7,),
#  (3,),
#  (5,),
#  (5,),
#  (5,),
#  (4,),
#  (5,),
#  (6,),
#  (3,),
#  (5,),
#  (7,),
#  (7,),
#  (1,),
#  (4,),
#  (6,),
#  (6,),
#  (7,),
#  (6,),
#  (4,),
#  (5,),
#  (5,),
#  (0,),
#  (5,),
#  (3,),
#  (6,),
#  (3,),
#  (4,),
#  (7,),
#  (7,),
#  (5,),
#  (6,),
#  (0,),
#  (4,),
#  (5,),
#  (3,),
#  (6,),
#  (4,),
#  (5,),
#  (0,),
#  (3,),
#  (4,),
#  (5,),
#  (3,),
#  (4,),
#  (4,),
#  (4,),
#  (5,),
#  (6,),
#  (4,),
#  (7,),
#  (6,),
#  (6,),
#  (7,),
#  (6,),
#  (4,),
#  (6,),
#  (5,),
#  (4,),
#  (7,),
#  (7,),
#  (7,),
#  (6,),
#  (3,),
#  (3,),
#  (5,),
#  (4,),
#  (3,),
#  (6,),
#  (7,),
#  (4,),
#  (5,),
#  (4,),
#  (4,),
#  (7,),
#  (6,),
#  (6,),
#  (3,),
#  (4,),
#  (4,),
#  (2,),
#  (6,),
#  (5,),
#  (6,),
#  (5,),
#  (8,),
#  (5,),
#  (1,),
#  (4,),
#  (5,),
#  (4,),
#  (4,),
#  (3,),
#  (3,),
#  (7,),
#  (4,),
#  (8,),
#  (6,),
#  (6,),
#  (3,),
#  (7,),
#  (5,),
#  (3,),
#  (6,),
#  (6,),
#  (5,),
#  (3,),
#  (5,),
#  (4,),
#  (6,),
#  (2,),
#  (7,),
#  (6,),
#  (2,),
#  (6,),
#  (5,),
#  (6,),
#  (0,),
#  (0,),
#  (6,),
#  (3,),
#  (0,),
#  (5,),
#  (7,),
#  (4,),
#  (4,),
#  (0,),
#  (7,),
#  (5,),
#  (5,),
#  (6,),
#  (9,),
#  (4,),
#  (6,),
#  (7,),
#  (3,),
#  (4,),
#  (3,),
#  (5,),
#  (6,),
#  (4,),
#  (6,),
#  (0,),
#  (4,),
#  (6,),
#  (5,),
#  (7,),
#  (7,),
#  (6,),
#  (6,),
#  (3,),
#  (4,),
#  (7,),
#  (3,),
#  (6,),
#  (0,),
#  (0,),
#  (4,),
#  (7,),
#  (5,),
#  (8,),
#  (4,),
#  (5,),
#  (9,),
#  (4,),
#  (6,),
#  (6,),
#  (7,),
#  (5,),
#  (4,),
#  (0,),
#  (4,),
#  (0,),
#  (6,),
#  (3,),
#  (5,),
#  (3,),
#  (8,),
#  (7,),
#  (6,),
#  (5,),
#  (6,),
#  (6,),
#  (5,),
#  (6,),
#  (6,),
#  (6,),
#  (3,),
#  (7,),
#  (6,),
#  (5,),
#  (3,),
#  (4,),
#  (6,),
#  (7,),
#  (1,),
#  (6,),
#  (6,),
#  (5,),
#  (8,),
#  (6,),
#  (5,),
#  (5,),
#  (3,),
#  (4,),
#  (4,),
#  (5,),
#  (8,),
#  (8,),
#  (0,),
#  (6,),
#  (6,),
#  (3,),
#  (5,),
#  (0,),
#  (5,),
#  (4,),
#  (5,),
#  (2,),
#  (8,),
#  (6,),
#  (0,),
#  (0,),
#  (8,),
#  (7,),
#  (4,),
#  (7,),
#  (7,),
#  (7,),
#  (4,),
#  (3,),
#  (0,),
#  ...]

# %% [markdown]
# # EDA
# * highest sale for each animal
# * total sales per animal
# * how many repeated purchase
# * the price of the most expensive food for fish
# * highest rating of each category
# * total sale for fish equipments
# * how many medium cat medicine were sold

# %% [markdown]
# # Seeing The Dataset

# %%
# %%sql
# select *
# from pet_supplies
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 1500 rows affected.
# [(1, 'Food', 'Bird', 'large', '51.1', 1860.62, '7', 1),
#  (3, 'Food', 'Dog', 'medium', '31.23', 898.3, '5', 1),
#  (4, 'Medicine', 'Cat', 'small', '24.95', 982.15, '6', 1),
#  (8, 'Toys', 'Cat', 'medium', '28.9', 1074.31, '4', 0),
#  (10, 'Medicine', 'Dog', 'medium', '24.93', 838.88, '8', 0),
#  (14, 'Food', 'Dog', 'large', '40.8', 1450.5, '6', 1),
#  (15, 'Accessory', 'Bird', 'medium', '33.13', 859.29, '4', 1),
#  (16, 'Accessory', 'Bird', 'large', '43.09', 1418.72, '1', 1),
#  (17, 'Equipment', 'Cat', 'small', '28.29', 1040.51, '5', 1),
#  (18, 'Toys', 'Bird', 'medium', '43.91', 1521.51, '3', 1),
#  (20, 'Toys', 'Dog', 'large', '44', 1792.63, '7', 1),
#  (11, 'Food', 'Dog', 'large', '40.87', 1457.22, '7', 1),
#  (22, 'Food', 'Dog', 'large', '41', 1456.58, '3', 0),
#  (24, 'Equipment', 'Cat', 'medium', '22.99', 790.26, '4', 0),
#  (26, 'Housing', 'Bird', 'large', '45.83', 1551.24, '4', 1),
#  (28, 'Equipment', 'Cat', 'small', '28.19', 1036.72, '5', 1),
#  (32, 'Housing', 'Cat', 'small', '26.07', 830.8, '7', 0),
#  (33, 'Equipment', 'Cat', 'small', '28.02', 1027.95, '6', 0),
#  (34, 'Toys', 'Fish', 'medium', '23.99', 743.83, '5', 0),
#  (115, 'Equipment', 'Dog', 'small', '32.98', 1106.85, '6', 1),
#  (116, 'Accessory', 'Fish', 'large', '22.75', 670.79, '3', 0),
#  (113, 'Housing', 'Bird', 'large', '45.99', 1558.19, '6', 0),
#  (118, 'Equipment', 'Cat', 'small', '28.03', 1029.38, '6', 1),
#  (119, 'Equipment', 'Cat', 'small', '27.7', 1021.27, '4', 0),
#  (120, 'Toys', 'Cat', 'medium', '29.02', 1073.29, '6', 1),
#  (139, 'Accessory', 'Bird', 'large', '42.85', 1411.53, '5', 0),
#  (123, 'Food', 'Dog', 'medium', '30.92', 885.87, '4', 1),
#  (126, 'Equipment', 'Cat', 'small', '27.99', 1028.27, '6', 0),
#  (127, 'Medicine', 'Cat', 'small', '25.07', 999.58, '8', 1),
#  (164, 'Medicine', 'Fish', 'large', '24.94', 941.39, '6', 0),
#  (129, 'Equipment', 'Cat', 'medium', '22.98', 795.34, '7', 0),
#  (225, 'Food', 'Fish', 'large', '31.08', 1020.19, '3', 0),
#  (226, 'Medicine', 'Cat', 'small', '25.16', 989.87, '4', 1),
#  (227, 'Housing', 'Fish', 'large', '26.13', 786.17, '4', 1),
#  (228, 'Food', 'Bird', 'large', '50.84', 1846.82, '6', 1),
#  (229, 'Equipment', 'Dog', 'small', '32.91', 1093.36, '3', 0),
#  (230, 'Equipment', 'Cat', 'small', '28.17', 1034.28, '5', 0),
#  (251, 'Equipment', 'Dog', 'large', '38.32', 1461.63, '6', 0),
#  (233, '-', 'Cat', 'small', '27.74', 1024.25, '6', 1),
#  (234, 'Food', 'Cat', 'large', '36.03', 1400.69, '7', 1),
#  (235, 'Food', 'Dog', 'medium', '30.75', 880.03, '5', 0),
#  (285, 'Food', 'Dog', 'large', '41.11', 1467.21, '4', 1),
#  (339, 'Food', 'Bird', 'medium', '41', 1208.27, '5', 1),
#  (340, 'Toys', 'Fish', 'small', '29.13', 965.84, '5', 1),
#  (341, 'Medicine', 'Fish', 'small', '19.84', 657.38, '5', 0),
#  (343, 'Toys', 'Fish', 'large', '33.78', 1283.93, '4', 1),
#  (344, '-', 'Cat', 'small', '27.78', 1026.38, '6', 0),
#  (385, 'Toys', 'Fish', 'large', '34.09', 1301.35, '9', 1),
#  (348, 'Equipment', 'Dog', 'medium', '28.05', 870.3, '3', 1),
#  (349, 'Medicine', 'Bird', 'medium', '34.96', 1200.15, '4', 0),
#  (350, 'Housing', 'Dog', 'small', '30.73', 869.43, '6', 1),
#  (351, 'Medicine', 'Fish', 'small', '19.99', 663.63, '6', 1),
#  (352, 'Equipment', 'Cat', 'small', '28.11', 1040.53, '7', 1),
#  (353, 'Housing', 'Bird', 'large', '46.16', 1557.58, '3', 1),
#  (354, 'Accessory', 'Bird', 'large', '42.93', 1409.97, '3', 1),
#  (355, 'Equipment', 'Cat', 'small', '27.99', 1044.51, '8', 1),
#  (303, 'Equipment', 'Cat', 'small', '28', 1025.83, '4', 1),
#  (305, 'Equipment', 'Fish', 'small', '22.98', 707.63, '5', 0),
#  (211, 'Equipment', 'Fish', 'small', '22.9', 700.8, '3', 0),
#  (308, 'Equipment', 'Cat', 'medium', '22.93', 787.3, '3', 1),
#  (309, 'Toys', 'Cat', 'small', '34.12', 1364.65, '6', 0),
#  (311, 'Medicine', 'Dog', 'medium', '25.19', 846.27, '5', 1),
#  (215, 'Food', 'Bird', 'small', '45.83', 1461.36, '4', 0),
#  (315, 'Accessory', 'Bird', 'medium', '33.1', 860.69, '5', 0),
#  (317, 'Equipment', 'Cat', 'small', '28.42', 1045.29, '5', 1),
#  (319, 'Food', 'Fish', 'medium', '20.89', 538.41, '5', 0),
#  (222, 'Food', 'Fish', 'small', '25.84', 729.2, '4', 1),
#  (321, 'Housing', 'Cat', 'small', '25.81', 820.54, '5', 1),
#  (322, 'Equipment', 'Cat', 'small', '27.91', 1030.16, '5', 0),
#  (323, 'Food', 'Bird', 'medium', '41.01', 1210.66, '4', 0),
#  (325, 'Toys', 'Cat', 'small', '34.53', 1356.71, '8', 1),
#  (326, 'Food', 'Fish', 'medium', '21.02', 543.87, '4', 0),
#  (327, 'Equipment', 'Fish', 'small', '23.28', 716.79, '4', 1),
#  (563, 'Food', 'Fish', 'small', '26.06', 740.27, '5', 1),
#  (604, 'Accessory', 'Bird', 'large', '43.01', 1417.0, '5', 0),
#  (633, 'Food', 'Cat', 'large', '36.05', 1409.62, '3', 1),
#  (567, 'Toys', 'Cat', 'small', '34.33', 1374.83, '5', 0),
#  (568, 'Food', 'Dog', 'medium', '30.96', 885.69, '4', 1),
#  (569, 'Equipment', 'Cat', 'small', '27.94', 1030.84, '5', 1),
#  (570, 'Food', 'Dog', 'medium', '30.94', 887.11, '3', 0),
#  (653, 'Toys', 'Bird', 'large', '54.02', 2254.99, '8', 0),
#  (574, 'Equipment', 'Dog', 'small', '33.11', 1107.81, '2', 0),
#  (575, 'Toys', 'Fish', 'small', '28.74', 963.92, '5', 0),
#  (576, 'Medicine', 'Cat', 'medium', '20.09', 741.2, '5', 0),
#  (577, 'Toys', 'Cat', 'medium', '29.16', 1084.45, '5', 1),
#  (390, 'Equipment', 'Fish', 'small', '22.93', 702.94, '5', 0),
#  (579, 'Equipment', 'Cat', 'small', '27.79', 1026.51, '5', 0),
#  (580, 'Toys', 'Dog', 'large', '44', 1790.98, '9', 0),
#  (677, 'Toys', 'Cat', 'medium', '29.22', 1083.7, '8', 0),
#  (678, 'Medicine', 'Cat', 'small', '24.9', 981.78, '8', 0),
#  (679, 'Medicine', 'Fish', 'medium', '15.21', 465.62, '5', 1),
#  (681, 'Medicine', 'Cat', 'small', '25', 992.35, '8', 0),
#  (682, 'Medicine', 'Fish', 'medium', '14.96', 462.92, '6', 1),
#  (683, 'Housing', 'Cat', 'small', '25.82', 818.94, '5', 1),
#  (684, 'Toys', 'Cat', 'medium', '28.93', 1074.29, '4', 1),
#  (685, 'Food', 'Dog', 'small', '35.84', 1116.7, '5', 0),
#  (686, 'Medicine', 'Fish', 'medium', '14.96', 459.81, '4', 1),
#  (687, 'Equipment', 'Dog', 'medium', '27.97', 866.65, '6', 0),
#  (689, 'Food', 'Cat', 'small', '30.84', 1064.04, '4', 1),
#  (691, 'Housing', 'Cat', 'small', '25.95', 824.36, '7', 1),
#  (788, 'Toys', 'Cat', 'small', '34.29', 1349.46, '4', 0),
#  (790, 'Food', 'Bird', 'small', '46.22', 1469.39, '5', 0),
#  (835, 'Housing', 'Fish', 'large', '25.93', 781.99, '4', 0),
#  (792, 'Equipment', 'Cat', 'small', '27.78', 1030.51, '5', 1),
#  (795, 'Housing', 'Dog', 'small', '31.06', 880.33, '3', 0),
#  (796, 'Housing', 'Fish', 'large', '25.87', 778.46, '4', 1),
#  (798, 'Toys', 'Cat', 'small', '34.08', 1348.14, '7', 0),
#  (850, 'Food', 'Dog', 'large', '40.97', 1452.61, '6', 0),
#  (802, 'Housing', 'Fish', 'medium', '16.02', 368.24, '4', 1),
#  (803, 'Housing', 'Fish', 'large', '25.82', 776.97, '5', 0),
#  (804, 'Food', 'Dog', 'medium', '30.9', 885.44, '3', 0),
#  (860, 'Accessory', 'Dog', 'large', '33.13', 1063.88, '4', 1),
#  (809, 'Toys', 'Fish', 'medium', '23.89', 747.3, '3', 1),
#  (900, 'Toys', 'Fish', 'large', '34.1', 1300.55, '9', 0),
#  (904, 'Medicine', 'Fish', 'small', '20.02', 666.64, '3', 1),
#  (905, 'Equipment', 'Cat', 'small', '28.06', 1037.46, '4', 1),
#  (906, 'Housing', 'Dog', 'medium', '26.15', 677.08, '3', 1),
#  (907, 'Food', 'Cat', 'small', '31.08', 1068.61, '5', 0),
#  (910, 'Equipment', 'Cat', 'medium', '22.99', 790.78, '6', 1),
#  (929, 'Housing', 'Dog', 'large', '36.09', 1186.89, '8', 1),
#  (912, 'Accessory', 'Bird', 'large', '42.93', 1412.1, '4', 1),
#  (916, 'Equipment', 'Bird', 'small', '43.1', 1481.11, '7', 0),
#  (917, 'Medicine', 'Fish', 'small', '20.04', 667.84, '6', 0),
#  (918, 'Medicine', 'Fish', 'medium', '14.96', 460.07, '6', 0),
#  (919, 'Equipment', 'Fish', 'small', '23.06', 704.66, '3', 1),
#  (921, 'Toys', 'Cat', 'small', '34.08', 1355.69, '7', 1),
#  (922, 'Accessory', 'Fish', 'small', '17.95', 441.1, '3', 1),
#  (923, 'Equipment', 'Cat', 'small', '27.99', 1028.67, '6', 0),
#  (946, 'Toys', 'Dog', 'large', '43.85', 1788.28, '8', 1),
#  (950, 'Housing', 'Fish', 'large', '26.08', 784.59, '6', 1),
#  (926, 'Food', 'Dog', 'medium', '31.15', 899.82, '4', 0),
#  (1012, 'Toys', 'Dog', 'medium', '34.03', 1150.04, '5', 0),
#  (1013, 'Toys', 'Cat', 'medium', '28.94', 1080.7, '6', 1),
#  (1014, 'Housing', 'Dog', 'large', '36.03', 1190.53, '5', 0),
#  (1016, 'Equipment', 'Cat', 'small', '28.07', 1034.77, '7', 1),
#  (1017, 'Equipment', 'Fish', 'medium', '17.99', 508.73, '4', 0),
#  (1079, 'Accessory', 'Bird', 'large', '42.86', 1412.95, '3', 1),
#  (1020, 'Medicine', 'Cat', 'small', '25.26', 1002.5, '7', 1),
#  (1023, 'Housing', 'Fish', 'small', '20.82', 528.85, '4', 1),
#  (1024, 'Medicine', 'Fish', 'large', '24.85', 936.86, '6', 1),
#  (1027, 'Food', 'Bird', 'small', '46.04', 1475.75, '5', 0),
#  (1028, 'Food', 'Dog', 'small', '36.16', 1121.08, '7', 0),
#  (1029, 'Equipment', 'Cat', 'small', '28', 1031.79, '3', 0),
#  (1030, 'Equipment', 'Cat', 'medium', '23.11', 796.9, '6', 1),
#  (1031, 'Equipment', 'Fish', 'medium', '18.13', 513.32, '4', 1),
#  (1032, 'Food', 'Dog', 'large', '41.12', 1464.05, '6', 0),
#  (1033, 'Food', 'Bird', 'small', '46.11', 1478.87, '6', 0),
#  (1034, 'Toys', 'Fish', 'small', '29.24', 971.18, '4', 1),
#  (1035, 'Medicine', 'Fish', 'small', '19.87', 654.6, '4', 1),
#  (1036, 'Accessory', 'Cat', 'large', '28.01', 996.05, '5', 0),
#  (1138, 'Accessory', 'Dog', 'large', '32.96', 1060.28, '7', 1),
#  (1126, 'Equipment', 'Cat', 'small', '27.95', 1036.83, '6', 0),
#  (1127, 'Accessory', 'Dog', 'medium', '23.23', 580.21, '2', 1),
#  (1128, 'Medicine', 'Cat', 'small', '24.82', 975.39, '6', 0),
#  (1129, 'Housing', 'Fish', 'medium', '16.31', 377.85, '6', 0),
#  (1130, 'Food', 'Dog', 'small', '36.01', 1116.83, '6', 0),
#  (1131, 'Toys', 'Bird', 'medium', '43.95', 1528.36, '6', 1),
#  (1132, 'Housing', 'Cat', 'large', '30.92', 1121.0, '6', 1),
#  (1133, 'Housing', 'Bird', 'large', '46.03', 1554.87, '5', 1),
#  (1134, 'Medicine', 'Bird', 'small', '40.12', 1496.24, '8', 1),
#  (1135, 'Food', 'Dog', 'large', '41.03', 1458.21, '6', 1),
#  (1137, 'Toys', 'Cat', 'small', '33.87', 1349.94, '6', 0),
#  (1235, 'Medicine', 'Dog', 'medium', '24.96', 838.39, '6', 0),
#  (1236, 'Toys', 'Fish', 'medium', '23.91', 741.86, '4', 1),
#  (1237, 'Equipment', 'Bird', 'medium', '38.18', 1220.59, '4', 1),
#  (1238, 'Housing', 'Dog', 'medium', '25.96', 676.39, '2', 1),
#  (1239, 'Accessory', 'Dog', 'large', '33.11', 1070.83, '3', 0),
#  (1254, 'Medicine', 'Fish', 'large', '24.91', 944.66, '5', 1),
#  (1241, 'Accessory', 'Dog', 'medium', '23.02', 579.38, '4', 1),
#  (1242, 'Equipment', 'Fish', 'small', '23.06', 705.4, '4', 1),
#  (1244, 'Food', 'Fish', 'large', '31.03', 1019.89, '5', 1),
#  (1245, 'Housing', 'Dog', 'medium', '26.08', 682.44, '5', 1),
#  (1247, 'Toys', 'Fish', 'small', '29.17', 979.77, '7', 0),
#  (328, 'Toys', 'Cat', 'medium', '28.86', 1064.54, '5', 1),
#  (232, 'Food', 'Fish', 'small', '25.83', 731.17, '6', 0),
#  (330, 'Equipment', 'Fish', 'small', '23.02', 708.63, '6', 1),
#  (331, 'Equipment', 'Cat', 'small', '27.98', 1036.31, '7', 1),
#  (333, 'Food', 'Fish', 'large', '30.99', 1020.05, '6', 1),
#  (334, 'Housing', 'Dog', 'medium', '25.99', 673.68, '5', 1),
#  (335, 'Toys', 'Dog', 'small', '39', 1411.57, '6', 1),
#  (336, 'Housing', 'Dog', 'medium', '25.98', 674.22, '4', 0),
#  (224, 'Accessory', 'Fish', 'large', '22.94', 669.84, '5', 1),
#  (137, 'Housing', 'Cat', 'small', '25.97', 823.94, '5', 1),
#  (138, 'Equipment', 'Fish', 'small', '23.14', 711.93, '4', 0),
#  (140, 'Toys', 'Cat', 'small', '34.08', 1348.96, '6', 1),
#  (41, 'Food', 'Cat', 'small', '31.2', 1074.63, '3', 1),
#  (142, 'Equipment', 'Cat', 'medium', '22.97', 790.52, '5', 1),
#  (143, 'Toys', 'Fish', 'medium', '24.24', 749.2, '6', 1),
#  (144, 'Food', 'Bird', 'medium', '41.02', 1204.42, '3', 1),
#  (145, 'Equipment', 'Cat', 'small', '27.95', 1025.34, '8', 0),
#  (146, 'Food', 'Dog', 'large', '41.04', 1456.69, '8', 0),
#  (147, 'Equipment', 'Fish', 'small', '22.68', 697.2, '2', 0),
#  (148, 'Medicine', 'Cat', 'small', '24.83', 981.35, '7', 1),
#  (149, 'Equipment', 'Cat', 'small', '27.77', 1022.07, '5', 0),
#  (150, 'Equipment', 'Cat', 'small', '27.99', 1026.36, '6', 1),
#  (151, 'Food', 'Bird', 'large', '50.92', 1859.84, '5', 1),
#  (152, 'Food', 'Dog', 'large', '41.01', 1464.8, '4', 1),
#  (154, 'Housing', 'Cat', 'medium', '21.12', 619.13, '4', 1),
#  (155, 'Housing', 'Fish', 'medium', '16.11', 373.72, '5', 0),
#  (157, 'Food', 'Bird', 'small', '45.83', 1460.05, '6', 1),
#  (35, 'Equipment', 'Cat', 'small', '28.25', 1039.58, '6', 1),
#  (36, 'Food', 'Dog', 'medium', '30.87', 879.37, '4', 1),
#  (37, 'Equipment', 'Cat', 'small', '28.09', 1034.96, '7', 1),
#  (39, 'Housing', 'Fish', 'large', '26.13', 783.84, '6', 1),
#  (40, 'Toys', 'Bird', 'large', '54.03', 2248.63, '5', 0),
#  (42, 'Food', 'Cat', 'small', '30.92', 1064.79, '7', 0),
#  (43, 'Housing', 'Cat', 'medium', '20.95', 615.07, '5', 1),
#  (44, 'Equipment', 'Fish', 'medium', '17.98', 506.75, '3', 1),
#  (55, 'Equipment', 'Dog', 'large', '38.06', 1449.87, '5', 1),
#  (46, 'Accessory', 'Dog', 'large', '32.98', 1063.91, '5', 1),
#  (88, 'Food', 'Dog', 'large', '40.93', 1463.29, '4', 1),
#  (48, 'Equipment', 'Cat', 'small', '27.7', 1022.95, '8', 0),
#  (49, 'Medicine', 'Cat', 'small', '24.8', 978.64, '6', 1),
#  (50, 'Food', 'Cat', 'small', '31.2', 1074.1, '6', 0),
#  (52, 'Medicine', 'Fish', 'small', '19.83', 658.66, '7', 1),
#  (53, 'Accessory', 'Dog', 'large', '33.15', 1068.44, '7', 0),
#  (54, 'Food', 'Fish', 'medium', '21.25', 548.05, '4', 0),
#  (57, 'Medicine', 'Dog', 'large', '35.04', 1424.02, '6', 1),
#  (59, 'Toys', 'Dog', 'medium', '33.94', 1152.57, '6', 0),
#  (61, 'Accessory', 'Dog', 'large', '32.99', 1068.83, '4', 1),
#  (62, 'Equipment', 'Fish', 'medium', '17.9', 506.2, '3', 1),
#  (63, 'Food', 'Fish', 'large', '30.96', 1016.49, '5', 0),
#  (64, 'Food', 'Dog', 'large', '40.93', 1459.08, '3', 0),
#  (65, 'Medicine', 'Dog', 'medium', '24.98', 836.05, '5', 1),
#  (66, 'Housing', 'Cat', 'small', '26.08', 831.86, '4', 1),
#  (67, 'Equipment', 'Fish', 'small', '23.08', 710.55, '5', 0),
#  (69, 'Equipment', 'Cat', 'medium', '22.95', 790.28, '6', 0),
#  (70, 'Toys', 'Dog', 'small', '39.03', 1411.58, '6', 0),
#  (99, 'Equipment', 'Dog', 'large', '38', 1447.26, '5', 0),
#  (72, 'Medicine', 'Bird', 'medium', '34.96', 1207.21, '6', 1),
#  (73, '-', 'Dog', 'small', '33.13', 1101.89, '4', 0),
#  (5, 'Housing', 'Cat', 'small', '26.18', 832.63, '7', 1),
#  (75, 'Equipment', 'Fish', 'small', '23.19', 706.38, '6', 1),
#  (76, 'Food', 'Fish', 'large', '31', 1023.95, '6', 1),
#  (77, 'Housing', 'Cat', 'medium', '21.05', 614.54, '3', 1),
#  (79, 'Medicine', 'Cat', 'small', '24.7', 975.88, '6', 1),
#  (81, 'Accessory', 'Cat', 'medium', '18.06', 518.45, '6', 1),
#  (82, 'Equipment', 'Fish', 'small', '22.99', 709.87, '2', 0),
#  (83, 'Equipment', 'Cat', 'small', '28.43', 1047.28, '5', 1),
#  (84, 'Toys', 'Bird', 'medium', '43.99', 1534.9, '7', 0),
#  (6, 'Housing', 'Dog', 'small', '30.77', 874.58, '7', 0),
#  (86, 'Food', 'Bird', 'medium', '41.03', 1206.69, '6', 1),
#  (87, 'Equipment', 'Cat', 'small', '28.28', 1042.37, '5', 0),
#  (89, 'Housing', 'Cat', 'small', '25.96', 825.63, '4', 0),
#  (7, 'Housing', 'Dog', 'small', '31.04', 875.07, '5', 0),
#  (91, 'Equipment', 'Cat', 'small', '27.86', 1022.0, '6', 1),
#  (92, 'Toys', 'Dog', 'small', '38.95', 1418.52, '6', 1),
#  (93, 'Housing', 'Bird', 'medium', '36.22', 965.85, '4', 0),
#  (94, 'Accessory', 'Dog', 'medium', '23.02', 578.95, '5', 0),
#  (19, 'Toys', 'Cat', 'small', '33.87', 1333.9, '6', 0),
#  (97, 'Accessory', 'Bird', 'large', '42.99', 1417.24, '5', 0),
#  (25, 'Toys', 'Dog', 'small', '38.99', 1410.66, '3', 0),
#  (103, 'Medicine', 'Dog', 'medium', '25.07', 846.96, '4', 0),
#  (104, 'Medicine', 'Fish', 'medium', '15', 464.88, '6', 1),
#  (105, 'Housing', 'Bird', 'medium', '35.95', 962.13, '2', 1),
#  (106, 'Equipment', 'Cat', 'small', '27.86', 1027.49, '3', 0),
#  (107, 'Medicine', 'Cat', 'large', '30.03', 1321.82, '8', 1),
#  (109, 'Equipment', 'Cat', 'small', '27.97', 1028.72, '5', 1),
#  (110, 'Toys', 'Fish', 'small', '28.74', 969.57, '4', 1),
#  (27, 'Equipment', 'Cat', 'small', '28.24', 1046.0, '4', 0),
#  (112, 'Food', 'Cat', 'medium', '26.05', 829.81, '6', 1),
#  (2, 'Housing', 'Bird', 'medium', '35.98', 963.6, '6', 0),
#  (9, 'Equipment', 'Fish', 'medium', '17.82', 503.67, '5', 0),
#  (133, 'Housing', 'Bird', 'large', '0', 1556.37, '0', 1),
#  (279, 'Medicine', 'Cat', 'small', '0', 986.94, '0', 0),
#  (307, 'Equipment', 'Cat', 'small', '0', 1034.74, '0', 1),
#  (347, 'Accessory', 'Cat', 'small', '0', 706.7, '0', 1),
#  (406, 'Food', 'Cat', 'small', '0', 1065.98, '0', 1),
#  (471, 'Toys', 'Cat', 'small', '0', 1354.1, '0', 1),
#  (12, 'Medicine', 'Bird', 'medium', '34.96', 1204.6, '5', 1),
#  (13, 'Food', 'Dog', 'medium', '31.07', 889.73, '4', 0),
#  (23, '-', 'Bird', 'medium', '32.98', 859.94, '3', 0),
#  (58, 'Housing', 'Dog', 'medium', '26.03', 678.99, '3', 0),
#  (68, 'Housing', 'Dog', 'medium', '26', 675.06, '3', 1),
#  (96, 'Housing', 'Cat', 'medium', '21.14', 617.64, '7', 1),
#  (29, 'Equipment', 'Cat', 'small', '27.79', 1031.11, '7', 1),
#  (30, 'Toys', 'Dog', 'small', '38.86', 1405.4, '5', 1),
#  (31, 'Equipment', 'Fish', 'small', '22.89', 706.94, '3', 1),
#  (38, 'Toys', 'Fish', 'small', '29.01', 966.05, '2', 0),
#  (130, 'Toys', 'Fish', 'large', '34.18', 1307.35, '4', 0),
#  (131, 'Housing', 'Fish', 'small', '21.07', 538.15, '4', 1),
#  (190, 'Food', 'Dog', 'large', '41.15', 1467.02, '6', 0),
#  (204, 'Housing', 'Bird', 'large', '45.94', 1541.46, '5', 0),
#  (216, 'Accessory', 'Dog', 'large', '33.03', 1062.88, '4', 1),
#  (221, 'Housing', 'Dog', 'large', '35.89', 1177.84, '5', 1),
#  (158, 'Medicine', 'Dog', 'small', '29.99', 1088.15, '3', 0),
#  (51, 'Food', 'Cat', 'small', '31.09', 1071.72, '6', 0),
#  (160, 'Toys', 'Fish', 'large', '34.17', 1299.15, '5', 1),
#  (162, 'Food', 'Dog', 'medium', '30.86', 880.28, '5', 1),
#  (163, 'Housing', 'Cat', 'small', '26.13', 827.52, '6', 1),
#  (165, 'Food', 'Bird', 'large', '51.18', 1869.97, '6', 1),
#  (167, 'Equipment', 'Cat', 'small', '27.93', 1031.5, '6', 1),
#  (168, 'Food', 'Cat', 'medium', '26.24', 837.67, '6', 1),
#  (170, 'Equipment', 'Cat', 'small', '28.17', 1041.59, '3', 0),
#  (171, 'Toys', 'Dog', 'small', '39.26', 1412.54, '4', 0),
#  (172, 'Toys', 'Cat', 'small', '34.17', 1350.32, '8', 0),
#  (174, '-', 'Bird', 'large', '51.1', 1868.47, '5', 0),
#  (175, 'Toys', 'Cat', 'small', '34.03', 1338.54, '6', 0),
#  (176, 'Food', 'Bird', 'medium', '41.08', 1204.46, '4', 1),
#  (177, 'Medicine', 'Dog', 'medium', '25.05', 844.17, '5', 1),
#  (179, '-', 'Bird', 'large', '50.99', 1855.16, '5', 1),
#  (180, 'Housing', 'Fish', 'medium', '15.91', 367.02, '5', 0),
#  (181, 'Housing', 'Fish', 'small', '20.79', 529.93, '3', 0),
#  (182, 'Food', 'Bird', 'medium', '40.88', 1206.88, '7', 1),
#  (183, 'Food', 'Fish', 'small', '26.3', 740.93, '3', 1),
#  (186, 'Toys', 'Dog', 'medium', '34.02', 1158.66, '5', 0),
#  (56, 'Food', 'Cat', 'small', '30.89', 1059.94, '6', 0),
#  (188, 'Medicine', 'Fish', 'small', '20.03', 663.35, '5', 1),
#  (189, 'Food', 'Fish', 'small', '26.67', 752.3, '3', 1),
#  (191, 'Equipment', 'Dog', 'small', '33.1', 1118.36, '3', 0),
#  (192, 'Equipment', 'Cat', 'small', '28.31', 1048.92, '8', 1),
#  (193, 'Medicine', 'Dog', 'medium', '25.06', 842.46, '3', 1),
#  (60, 'Housing', 'Cat', 'small', '25.81', 814.06, '3', 0),
#  (195, 'Food', 'Cat', 'small', '31.04', 1074.04, '4', 0),
#  (196, 'Equipment', 'Cat', 'small', '27.98', 1029.34, '7', 0),
#  (198, 'Equipment', 'Cat', 'small', '27.65', 1019.82, '6', 0),
#  (199, 'Equipment', 'Dog', 'small', '33.09', 1110.67, '3', 1),
#  (78, 'Food', 'Cat', 'small', '31.5', 1090.84, '6', 0),
#  (206, 'Toys', 'Dog', 'small', '38.87', 1408.33, '4', 1),
#  (207, 'Medicine', 'Cat', 'medium', '20.05', 740.8, '4', 0),
#  (208, 'Medicine', 'Fish', 'small', '19.86', 659.93, '3', 0),
#  (80, 'Accessory', 'Dog', 'small', '27.76', 764.19, '3', 0),
#  (98, 'Equipment', 'Cat', 'small', '27.95', 1026.77, '6', 1),
#  (213, 'Toys', 'Bird', 'small', '48.91', 1816.23, '6', 1),
#  (214, 'Housing', 'Cat', 'small', '25.91', 822.17, '4', 1),
#  (217, 'Equipment', 'Cat', 'small', '27.89', 1029.56, '3', 1),
#  (218, 'Food', 'Dog', 'small', '35.97', 1111.28, '3', 0),
#  (100, 'Equipment', 'Cat', 'small', '28.2', 1035.18, '6', 1),
#  (220, 'Equipment', 'Fish', 'small', '23.16', 710.4, '2', 0),
#  (223, 'Medicine', 'Dog', 'large', '34.85', 1416.51, '7', 1),
#  (122, 'Equipment', 'Cat', 'medium', '23.19', 801.04, '3', 1),
#  (124, 'Housing', 'Dog', 'medium', '26.32', 685.86, '2', 1),
#  (153, 'Housing', 'Bird', 'medium', '36.08', 962.39, '5', 1),
#  (166, 'Medicine', 'Cat', 'medium', '20.06', 741.16, '4', 0),
#  (169, 'Food', 'Cat', 'medium', '25.88', 825.61, '5', 1),
#  (178, 'Medicine', 'Cat', 'medium', '19.88', 734.01, '8', 0),
#  (184, 'Equipment', 'Cat', 'medium', '22.86', 787.87, '4', 1),
#  (200, 'Equipment', 'Dog', 'medium', '28', 873.45, '2', 1),
#  (114, 'Housing', 'Cat', 'small', '25.83', 821.45, '8', 0),
#  (125, 'Equipment', 'Cat', 'small', '28.2', 1047.38, '5', 0),
#  (156, 'Food', 'Cat', 'small', '30.96', 1059.68, '7', 1),
#  (161, 'Medicine', 'Fish', 'small', '19.76', 657.92, '3', 1),
#  (173, 'Equipment', 'Cat', 'small', '28.07', 1034.36, '5', 1),
#  (185, 'Toys', 'Cat', 'small', '34.11', 1345.58, '6', 1),
#  (197, 'Medicine', 'Cat', 'small', '25.02', 992.22, '6', 1),
#  (203, 'Food', 'Bird', 'small', '46.02', 1470.55, '2', 1),
#  (237, 'Equipment', 'Fish', 'small', '23.05', 699.21, '3', 1),
#  (238, 'Toys', 'Fish', 'medium', '24.05', 747.39, '6', 0),
#  (240, 'Toys', 'Cat', 'small', '33.93', 1343.52, '6', 1),
#  (241, 'Equipment', 'Cat', 'medium', '23.28', 801.56, '3', 1),
#  (242, 'Toys', 'Cat', 'small', '34.01', 1347.06, '7', 1),
#  (243, 'Housing', 'Fish', 'medium', '16.23', 375.37, '4', 0),
#  (244, 'Housing', 'Dog', 'small', '30.92', 876.82, '6', 1),
#  (245, 'Toys', 'Fish', 'medium', '24.03', 745.79, '4', 0),
#  (246, 'Medicine', 'Cat', 'medium', '19.87', 734.24, '3', 1),
#  (247, 'Equipment', 'Cat', 'small', '27.97', 1034.03, '4', 0),
#  (248, 'Food', 'Fish', 'medium', '21.02', 544.63, '2', 1),
#  (249, 'Accessory', 'Bird', 'large', '42.97', 1420.58, '6', 1),
#  (292, 'Food', 'Bird', 'large', '50.9', 1861.97, '4', 1),
#  (252, 'Medicine', 'Cat', 'small', '24.96', 984.98, '7', 1),
#  (253, 'Accessory', 'Cat', 'small', '23.07', 722.66, '5', 1),
#  (254, 'Accessory', 'Fish', 'medium', '12.89', 288.01, '3', 0),
#  (255, 'Medicine', 'Cat', 'small', '25.09', 989.83, '6', 1),
#  (256, 'Equipment', 'Dog', 'small', '32.96', 1106.18, '5', 1),
#  (295, 'Toys', 'Bird', 'large', '54.05', 2249.4, '4', 0),
#  (258, 'Housing', 'Fish', 'small', '21.22', 540.81, '3', 0),
#  (259, 'Equipment', 'Cat', 'small', '28.33', 1044.42, '4', 0),
#  (260, 'Toys', 'Dog', 'small', '38.89', 1417.68, '5', 0),
#  (261, 'Food', 'Dog', 'small', '35.87', 1118.67, '6', 1),
#  (262, 'Equipment', 'Cat', 'small', '28.03', 1034.78, '6', 1),
#  (263, 'Food', 'Fish', 'small', '25.92', 729.11, '4', 1),
#  (264, 'Equipment', 'Fish', 'medium', '18.08', 511.72, '5', 1),
#  (265, 'Toys', 'Cat', 'small', '33.87', 1350.59, '6', 0),
#  (304, 'Food', 'Fish', 'large', '30.97', 1014.57, '3', 1),
#  (267, 'Toys', 'Fish', 'small', '28.92', 964.24, '4', 1),
#  (270, 'Medicine', 'Bird', 'medium', '35.03', 1207.13, '6', 1),
#  (272, 'Food', 'Dog', 'large', '41.04', 1470.65, '6', 1),
#  (273, 'Housing', 'Dog', 'small', '31.23', 884.46, '3', 1),
#  (275, 'Medicine', 'Fish', 'medium', '15.03', 464.98, '3', 1),
#  (276, 'Toys', 'Cat', 'medium', '29.01', 1074.06, '3', 1),
#  (332, 'Food', 'Dog', 'large', '41.14', 1466.3, '6', 1),
#  (278, 'Food', 'Dog', 'small', '35.99', 1120.11, '4', 0),
#  (102, 'Toys', 'Dog', 'small', '39.16', 1425.23, '3', 1),
#  (280, 'Toys', 'Dog', 'large', '43.9', 1795.77, '5', 1),
#  (281, 'Equipment', 'Cat', 'small', '28.2', 1034.1, '3', 1),
#  (282, 'Toys', 'Fish', 'small', '29', 972.44, '8', 1),
#  (283, 'Housing', 'Cat', 'large', '31.04', 1124.81, '5', 1),
#  (284, 'Food', 'Cat', 'medium', '26.1', 834.51, '4', 0),
#  (108, 'Equipment', 'Fish', 'small', '22.98', 712.43, '6', 0),
#  (202, 'Equipment', 'Fish', 'small', '23.01', 703.91, '3', 1),
#  (288, 'Equipment', 'Cat', 'small', '28.1', 1043.5, '7', 0),
#  (205, 'Equipment', 'Cat', 'small', '28.04', 1039.48, '5', 1),
#  (290, 'Equipment', 'Cat', 'small', '27.82', 1026.3, '8', 1),
#  (293, 'Food', 'Bird', 'large', '50.98', 1864.04, '6', 0),
#  (296, 'Toys', 'Fish', 'medium', '24.16', 747.43, '4', 1),
#  (297, 'Toys', 'Bird', 'medium', '43.92', 1525.97, '6', 1),
#  (209, 'Food', 'Dog', 'small', '35.99', 1122.98, '5', 1),
#  (300, 'Accessory', 'Dog', 'small', '27.82', 772.16, '5', 1),
#  (271, 'Toys', 'Dog', 'medium', '33.93', 1144.31, '5', 0),
#  (294, 'Toys', 'Cat', 'medium', '29.19', 1087.59, '4', 1),
#  (299, 'Medicine', 'Fish', 'medium', '15.05', 464.52, '6', 1),
#  (301, 'Food', 'Cat', 'medium', '26.06', 832.08, '6', 1),
#  (310, 'Accessory', 'Dog', 'medium', '22.92', 577.97, '3', 0),
#  (312, 'Food', 'Dog', 'medium', '30.85', 885.8, '4', 1),
#  (318, 'Food', 'Cat', 'medium', '26.08', 837.94, '4', 1),
#  (239, 'Equipment', 'Cat', 'small', '27.96', 1037.79, '5', 0),
#  (268, '-', 'Fish', 'small', '23.12', 708.32, '4', 1),
#  (269, 'Equipment', 'Cat', 'small', '27.87', 1020.96, '5', 1),
#  (274, 'Equipment', 'Fish', 'small', '22.93', 703.79, '5', 1),
#  (291, 'Toys', 'Cat', 'small', '34', 1346.68, '5', 0),
#  (302, 'Toys', 'Cat', 'small', '33.91', 1346.02, '6', 0),
#  (356, 'Medicine', 'Bird', 'medium', '34.88', 1198.81, '4', 1),
#  (358, 'Toys', 'Cat', 'small', '33.99', 1345.66, '6', 0),
#  (403, 'Accessory', 'Bird', 'large', '42.88', 1416.28, '5', 1),
#  (362, 'Housing', 'Bird', 'large', '46.11', 1565.71, '7', 0),
#  (363, 'Equipment', 'Fish', 'small', '22.91', 700.94, '3', 1),
#  (364, 'Accessory', 'Bird', 'medium', '33.11', 864.73, '4', 1),
#  (365, 'Accessory', 'Dog', 'large', '32.79', 1060.94, '5', 0),
#  (366, 'Equipment', 'Cat', 'medium', '23.07', 799.68, '5', 1),
#  (367, 'Equipment', 'Cat', 'small', '27.81', 1025.05, '7', 1),
#  (368, 'Food', 'Dog', 'medium', '30.89', 885.79, '5', 0),
#  (369, 'Equipment', 'Cat', 'small', '27.92', 1031.79, '3', 1),
#  (422, 'Food', 'Bird', 'large', '50.91', 1854.43, '7', 1),
#  (371, 'Medicine', 'Fish', 'small', '20.03', 665.55, '6', 1),
#  (372, 'Toys', 'Fish', 'small', '28.97', 961.73, '4', 1),
#  (374, 'Food', 'Fish', 'medium', '21.04', 540.38, '5', 1),
#  (306, 'Toys', 'Cat', 'small', '33.97', 1349.03, '6', 1),
#  (378, 'Medicine', 'Fish', 'small', '20.21', 666.75, '4', 1),
#  (380, 'Food', 'Dog', 'small', '35.76', 1112.35, '4', 1),
#  (381, 'Food', 'Fish', 'small', '25.76', 731.75, '4', 1),
#  (382, 'Medicine', 'Cat', 'small', '24.94', 979.15, '9', 0),
#  (383, 'Food', 'Fish', 'small', '26.05', 747.96, '2', 1),
#  (384, 'Equipment', 'Dog', 'medium', '28', 871.81, '5', 1),
#  (386, 'Equipment', 'Fish', 'medium', '18.08', 510.02, '4', 1),
#  (389, 'Medicine', 'Bird', 'medium', '35.11', 1216.53, '6', 0),
#  (391, 'Food', 'Bird', 'medium', '40.89', 1208.03, '4', 1),
#  (392, 'Housing', 'Dog', 'medium', '25.92', 674.67, '6', 1),
#  (393, 'Equipment', 'Cat', 'small', '28.15', 1034.36, '7', 1),
#  (314, 'Equipment', 'Cat', 'small', '28.18', 1036.46, '6', 0),
#  (316, 'Housing', 'Dog', 'small', '30.82', 881.02, '4', 1),
#  (396, 'Toys', 'Fish', 'medium', '23.86', 741.11, '6', 1),
#  (397, 'Medicine', 'Dog', 'medium', '24.8', 837.19, '4', 0),
#  (398, 'Equipment', 'Fish', 'small', '23.11', 716.78, '5', 0),
#  (399, 'Toys', 'Fish', 'large', '33.97', 1289.12, '6', 0),
#  (400, 'Accessory', 'Dog', 'large', '33.14', 1065.51, '2', 0),
#  (401, 'Equipment', 'Cat', 'small', '28.06', 1030.25, '7', 0),
#  (404, 'Housing', 'Fish', 'small', '21.36', 541.92, '4', 1),
#  (405, 'Food', 'Bird', 'large', '50.92', 1849.66, '5', 0),
#  (324, 'Toys', 'Cat', 'small', '33.84', 1346.25, '5', 1),
#  (407, 'Medicine', 'Fish', 'small', '19.95', 665.53, '6', 0),
#  (408, 'Toys', 'Cat', 'small', '34.24', 1361.1, '8', 0),
#  (409, 'Equipment', 'Cat', 'small', '28.04', 1035.07, '4', 0),
#  (410, 'Food', 'Bird', 'medium', '41.13', 1211.2, '5', 0),
#  (411, 'Housing', 'Cat', 'small', '26.19', 826.92, '3', 1),
#  (412, 'Housing', 'Cat', 'small', '26.44', 834.68, '4', 0),
#  (413, 'Housing', 'Dog', 'medium', '26.01', 673.05, '3', 0),
#  (414, 'Equipment', 'Cat', 'small', '27.98', 1036.29, '6', 0),
#  (337, 'Equipment', 'Cat', 'small', '27.84', 1030.21, '4', 0),
#  (416, 'Equipment', 'Cat', 'small', '27.94', 1035.28, '3', 1),
#  (417, 'Food', 'Fish', 'medium', '20.92', 539.64, '1', 1),
#  (418, 'Housing', 'Cat', 'large', '31.16', 1138.04, '7', 0),
#  (419, 'Toys', 'Fish', 'small', '29.13', 973.42, '6', 0),
#  (420, 'Equipment', 'Fish', 'small', '22.87', 700.78, '5', 1),
#  (421, 'Housing', 'Cat', 'medium', '21.03', 616.66, '6', 1),
#  (423, 'Equipment', 'Cat', 'small', '27.94', 1034.34, '5', 1),
#  (424, 'Housing', 'Bird', 'small', '41.01', 1191.23, '5', 0),
#  (426, 'Housing', 'Fish', 'large', '26', 782.43, '4', 0),
#  (342, 'Medicine', 'Cat', 'small', '24.85', 981.18, '4', 0),
#  (429, 'Food', 'Dog', 'small', '36.04', 1119.84, '7', 0),
#  (431, 'Toys', 'Fish', 'small', '29.02', 975.45, '6', 1),
#  (432, 'Accessory', 'Dog', 'large', '33.1', 1062.62, '5', 0),
#  (433, 'Toys', 'Dog', 'small', '38.84', 1417.22, '6', 1),
#  (436, 'Food', 'Fish', 'medium', '20.87', 543.76, '4', 1),
#  (438, 'Equipment', 'Cat', 'small', '28.04', 1040.72, '6', 1),
#  (439, 'Food', 'Dog', 'medium', '31.19', 898.42, '3', 1),
#  (441, 'Housing', 'Cat', 'medium', '21.03', 617.98, '3', 0),
#  (442, 'Toys', 'Bird', 'medium', '43.95', 1522.52, '4', 1),
#  (443, 'Food', 'Dog', 'large', '40.99', 1464.54, '5', 0),
#  (444, 'Equipment', 'Fish', 'medium', '18.01', 510.19, '2', 1),
#  (445, 'Toys', 'Fish', 'medium', '24.06', 744.96, '5', 1),
#  (446, 'Equipment', 'Cat', 'small', '27.99', 1029.53, '5', 1),
#  (447, 'Food', 'Bird', 'medium', '40.9', 1216.38, '5', 1),
#  (449, 'Toys', 'Bird', 'large', '54.16', 2248.04, '8', 1),
#  (450, 'Toys', 'Cat', 'small', '34.1', 1344.84, '6', 0),
#  (338, 'Food', 'Fish', 'medium', '21.02', 543.97, '3', 1),
#  (345, 'Food', 'Fish', 'medium', '21.02', 540.34, '2', 0),
#  (346, 'Accessory', 'Bird', 'medium', '33.15', 860.51, '6', 1),
#  (359, 'Toys', 'Bird', 'medium', '44.07', 1517.76, '5', 1),
#  (373, 'Equipment', 'Fish', 'medium', '18.12', 514.67, '3', 1),
#  (377, 'Equipment', 'Cat', 'medium', '22.88', 789.06, '4', 1),
#  (388, 'Food', 'Dog', 'medium', '31.08', 889.15, '5', 0),
#  (448, 'Toys', 'Fish', 'medium', '24.02', 742.64, '5', 1),
#  (357, 'Equipment', 'Cat', 'small', '28.36', 1044.03, '5', 0),
#  (360, 'Housing', 'Dog', 'small', '31.22', 877.81, '3', 1),
#  (454, 'Accessory', 'Bird', 'large', '43.12', 1434.65, '5', 0),
#  (458, 'Medicine', 'Cat', 'small', '25.17', 994.41, '9', 1),
#  (459, 'Medicine', 'Bird', 'large', '45.06', 1871.35, '8', 0),
#  (460, 'Medicine', 'Cat', 'small', '24.76', 970.57, '7', 1),
#  (461, 'Medicine', 'Fish', 'small', '20.09', 669.38, '6', 1),
#  (462, 'Housing', 'Dog', 'small', '31.09', 886.84, '3', 1),
#  (465, 'Equipment', 'Cat', 'medium', '22.99', 794.74, '5', 0),
#  (466, 'Food', 'Cat', 'medium', '26.15', 836.75, '4', 1),
#  (467, 'Toys', 'Bird', 'large', '53.97', 2246.77, '8', 1),
#  (469, 'Accessory', 'Bird', 'large', '43.04', 1422.27, '5', 1),
#  (470, 'Food', 'Bird', 'large', '51.04', 1861.15, '4', 1),
#  (452, 'Accessory', 'Bird', 'large', '42.82', 1417.18, '4', 0),
#  (456, 'Accessory', 'Bird', 'large', '42.92', 1411.82, '4', 0),
#  (473, 'Equipment', 'Cat', 'medium', '23.14', 797.38, '6', 0),
#  (474, 'Equipment', 'Cat', 'small', '28.3', 1047.8, '3', 0),
#  (478, 'Accessory', 'Dog', 'medium', '22.98', 578.38, '3', 1),
#  (479, 'Toys', 'Dog', 'small', '38.98', 1415.14, '4', 0),
#  (481, 'Medicine', 'Dog', 'medium', '25.06', 842.67, '5', 1),
#  (495, 'Food', 'Dog', 'large', '40.91', 1460.29, '6', 1),
#  (516, 'Housing', 'Fish', 'large', '25.93', 784.8, '3', 1),
#  (484, 'Toys', 'Fish', 'small', '29.01', 971.13, '6', 0),
#  (486, 'Accessory', 'Bird', 'large', '43.03', 1424.58, '5', 1),
#  (488, 'Housing', 'Fish', 'medium', '15.95', 369.07, '3', 1),
#  (490, 'Housing', 'Dog', 'small', '30.93', 886.42, '6', 1),
#  (491, 'Equipment', 'Cat', 'small', '27.83', 1025.24, '4', 1),
#  (525, 'Accessory', 'Dog', 'large', '33.06', 1063.55, '2', 0),
#  (493, 'Housing', 'Dog', 'small', '30.81', 864.88, '3', 1),
#  (494, 'Food', 'Bird', 'medium', '40.83', 1196.56, '4', 1),
#  (496, 'Food', 'Fish', 'small', '25.7', 727.87, '3', 1),
#  (497, 'Food', 'Cat', 'small', '31.03', 1072.2, '6', 1),
#  (498, 'Equipment', 'Dog', 'large', '37.89', 1440.06, '4', 1),
#  (500, 'Toys', 'Fish', 'large', '34.17', 1296.58, '5', 1),
#  (532, 'Food', 'Bird', 'large', '50.9', 1862.12, '7', 1),
#  (502, 'Housing', 'Bird', 'medium', '36.01', 962.21, '5', 0),
#  (503, 'Housing', 'Fish', 'medium', '16.17', 374.04, '4', 1),
#  (543, 'Housing', 'Dog', 'large', '36.09', 1187.66, '4', 1),
#  (505, 'Housing', 'Fish', 'medium', '15.94', 365.3, '4', 0),
#  (506, 'Housing', 'Bird', 'small', '40.97', 1204.78, '6', 1),
#  (507, 'Accessory', 'Bird', 'medium', '33.04', 861.89, '5', 1),
#  (508, 'Housing', 'Dog', 'medium', '26.2', 678.22, '2', 1),
#  (509, 'Toys', 'Dog', 'small', '39.19', 1419.66, '3', 1),
#  (511, 'Housing', 'Dog', 'medium', '26.03', 675.41, '7', 0),
#  (512, 'Food', 'Cat', 'large', '36', 1408.16, '6', 1),
#  (513, 'Toys', 'Dog', 'small', '38.66', 1403.4, '5', 0),
#  (514, 'Toys', 'Fish', 'medium', '23.95', 742.87, '7', 1),
#  (517, 'Medicine', 'Cat', 'small', '25.29', 1001.91, '7', 1),
#  (518, 'Toys', 'Dog', 'large', '44.03', 1797.02, '7', 1),
#  (520, 'Medicine', 'Cat', 'medium', '19.91', 735.01, '8', 1),
#  (521, 'Toys', 'Cat', 'small', '33.91', 1337.11, '9', 0),
#  (376, 'Equipment', 'Cat', 'small', '27.9', 1026.74, '6', 0),
#  (524, 'Medicine', 'Fish', 'small', '19.89', 661.23, '6', 0),
#  (526, 'Accessory', 'Bird', 'medium', '32.96', 856.75, '5', 1),
#  (529, 'Housing', 'Cat', 'small', '25.92', 820.26, '3', 0),
#  (530, 'Toys', 'Fish', 'small', '29.09', 979.48, '8', 1),
#  (531, 'Accessory', 'Fish', 'small', '18.09', 446.76, '3', 0),
#  (535, 'Toys', 'Cat', 'small', '34.03', 1347.16, '7', 1),
#  (536, 'Equipment', 'Cat', 'small', '28.03', 1035.32, '6', 0),
#  (537, 'Medicine', 'Dog', 'medium', '25.16', 846.37, '3', 0),
#  (379, 'Equipment', 'Cat', 'small', '27.88', 1032.4, '7', 1),
#  (387, 'Housing', 'Dog', 'small', '30.86', 871.1, '3', 0),
#  (540, 'Housing', 'Fish', 'large', '25.91', 775.92, '3', 1),
#  (451, 'Housing', 'Cat', 'small', '26.08', 822.27, '4', 1),
#  (544, 'Medicine', 'Fish', 'large', '24.88', 942.65, '6', 1),
#  (545, 'Accessory', 'Dog', 'medium', '22.93', 574.75, '1', 1),
#  (546, 'Toys', 'Cat', 'small', '34.28', 1354.57, '6', 1),
#  (547, 'Toys', 'Cat', 'medium', '29.05', 1079.88, '7', 1),
#  (550, 'Food', 'Fish', 'large', '31.16', 1028.57, '6', 0),
#  (551, 'Equipment', 'Cat', 'small', '28.27', 1048.08, '7', 1),
#  (552, 'Food', 'Fish', 'medium', '21.14', 548.11, '3', 0),
#  (553, 'Equipment', 'Dog', 'medium', '27.93', 871.63, '6', 1),
#  (554, 'Equipment', 'Fish', 'small', '22.97', 705.93, '5', 0),
#  (555, 'Toys', 'Cat', 'medium', '28.84', 1070.85, '4', 0),
#  (556, 'Medicine', 'Fish', 'medium', '14.94', 459.89, '6', 1),
#  (557, 'Medicine', 'Dog', 'large', '35.05', 1422.39, '7', 1),
#  (558, 'Toys', 'Cat', 'medium', '28.89', 1073.93, '4', 1),
#  (559, 'Equipment', 'Cat', 'small', '27.98', 1031.86, '5', 1),
#  (560, 'Toys', 'Dog', 'small', '39.21', 1421.19, '5', 0),
#  (561, 'Food', 'Dog', 'large', '41.12', 1469.55, '5', 1),
#  (562, 'Food', 'Bird', 'medium', '41', 1205.59, '4', 1),
#  (455, 'Accessory', 'Cat', 'medium', '17.95', 512.36, '3', 0),
#  (475, 'Medicine', 'Cat', 'medium', '19.94', 735.52, '6', 1),
#  (477, 'Medicine', 'Fish', 'medium', '14.99', 461.05, '5', 1),
#  (499, 'Equipment', 'Cat', 'medium', '22.9', 787.62, '6', 0),
#  (510, 'Medicine', 'Cat', 'medium', '19.97', 736.3, '6', 1),
#  (515, 'Accessory', 'Dog', 'medium', '22.88', 577.12, '4', 0),
#  (519, 'Food', 'Cat', 'medium', '25.9', 831.78, '3', 1),
#  (523, 'Housing', 'Dog', 'medium', '26.09', 671.89, '3', 0),
#  (541, 'Housing', 'Dog', 'medium', '25.98', 676.72, '3', 1),
#  (453, 'Toys', 'Fish', 'small', '28.98', 973.92, '6', 1),
#  (457, 'Food', 'Fish', 'small', '26.33', 750.33, '5', 1),
#  (463, 'Medicine', 'Dog', 'small', '29.98', 1081.52, '7', 1),
#  (464, 'Medicine', 'Fish', 'small', '19.98', 662.74, '3', 1),
#  (468, 'Housing', 'Dog', 'small', '30.96', 868.61, '6', 0),
#  (476, 'Food', 'Fish', 'small', '26.22', 735.94, '2', 0),
#  (582, 'Accessory', 'Dog', 'large', '32.97', 1058.07, '3', 1),
#  (584, 'Toys', 'Fish', 'medium', '23.82', 735.3, '5', 1),
#  (585, 'Food', 'Dog', 'large', '41.01', 1453.78, '6', 0),
#  (586, 'Equipment', 'Cat', 'medium', '23.33', 808.45, '4', 1),
#  (587, 'Housing', 'Bird', 'medium', '35.96', 965.12, '1', 1),
#  (588, 'Food', 'Bird', 'large', '50.99', 1855.21, '6', 1),
#  (589, 'Accessory', 'Bird', 'medium', '33', 861.52, '4', 0),
#  (590, 'Equipment', 'Fish', 'small', '23', 704.78, '4', 1),
#  (591, 'Food', 'Dog', 'medium', '31.16', 885.52, '3', 1),
#  (402, 'Toys', 'Fish', 'small', '28.85', 971.26, '4', 0),
#  (593, 'Equipment', 'Cat', 'small', '27.94', 1030.82, '4', 1),
#  (594, '-', 'Fish', 'medium', '17.95', 509.93, '5', 1),
#  (425, 'Equipment', 'Cat', 'small', '27.82', 1031.78, '6', 0),
#  (598, 'Equipment', 'Cat', 'small', '27.99', 1032.53, '5', 1),
#  (600, 'Medicine', 'Cat', 'medium', '19.99', 735.73, '3', 1),
#  (601, 'Equipment', 'Cat', 'medium', '23', 793.54, '3', 1),
#  (428, 'Equipment', 'Dog', 'small', '32.95', 1104.95, '5', 0),
#  (603, 'Equipment', 'Cat', 'small', '27.91', 1029.65, '4', 1),
#  (430, 'Medicine', 'Dog', 'small', '30.18', 1096.79, '4', 1),
#  (610, 'Medicine', 'Dog', 'medium', '25.2', 850.43, '7', 0),
#  (611, 'Food', 'Dog', 'medium', '30.92', 885.53, '6', 1),
#  (612, 'Food', 'Bird', 'medium', '41.15', 1207.5, '6', 1),
#  (613, 'Medicine', 'Dog', 'small', '30.08', 1084.15, '3', 1),
#  (614, 'Housing', 'Dog', 'small', '31.23', 893.06, '1', 1),
#  (615, 'Toys', 'Cat', 'small', '34.25', 1354.26, '8', 1),
#  (617, 'Housing', 'Dog', 'medium', '26.03', 670.66, '2', 1),
#  (618, 'Housing', 'Fish', 'large', '25.9', 778.16, '3', 1),
#  (619, 'Medicine', 'Dog', 'medium', '24.82', 833.26, '5', 1),
#  (434, 'Food', 'Bird', 'small', '45.78', 1456.48, '6', 0),
#  (621, 'Toys', 'Fish', 'small', '29.02', 967.03, '5', 1),
#  (622, 'Food', 'Bird', 'medium', '40.96', 1208.98, '5', 0),
#  (623, 'Food', 'Bird', 'large', '50.92', 1852.79, '4', 1),
#  (435, 'Housing', 'Cat', 'small', '26.29', 834.96, '5', 1),
#  (625, 'Housing', 'Cat', 'medium', '20.87', 609.01, '7', 0),
#  (626, 'Medicine', 'Fish', 'small', '20', 662.86, '5', 1),
#  (437, 'Toys', 'Cat', 'small', '33.89', 1340.5, '9', 1),
#  (628, 'Toys', 'Cat', 'small', '34.06', 1365.83, '9', 1),
#  (629, 'Housing', 'Fish', 'medium', '15.99', 372.62, '4', 0),
#  (631, 'Housing', 'Fish', 'medium', '15.95', 366.79, '4', 1),
#  (632, 'Equipment', 'Cat', 'small', '28.15', 1031.46, '6', 0),
#  (634, '-', 'Dog', 'medium', '28.1', 872.04, '4', 0),
#  (635, 'Medicine', 'Dog', 'medium', '25.04', 845.75, '4', 0),
#  (636, 'Medicine', 'Fish', 'medium', '15.16', 471.66, '6', 0),
#  (637, 'Housing', 'Cat', 'medium', '20.84', 610.48, '2', 1),
#  (638, 'Housing', 'Dog', 'medium', '25.97', 670.87, '4', 1),
#  (639, 'Toys', 'Dog', 'small', '39.09', 1424.13, '3', 1),
#  (640, 'Food', 'Dog', 'medium', '31.15', 886.18, '6', 0),
#  (641, 'Housing', 'Dog', 'large', '36.09', 1188.68, '4', 0),
#  (642, 'Equipment', 'Cat', 'small', '27.82', 1023.28, '9', 1),
#  (643, 'Toys', 'Cat', 'small', '33.86', 1336.18, '8', 0),
#  (644, 'Accessory', 'Cat', 'large', '28', 998.18, '4', 0),
#  (645, 'Food', 'Cat', 'small', '30.74', 1053.2, '5', 1),
#  (647, 'Equipment', 'Cat', 'medium', '22.87', 787.4, '7', 0),
#  (648, 'Equipment', 'Cat', 'small', '28.1', 1032.94, '4', 0),
#  (649, 'Food', 'Bird', 'large', '51.04', 1853.37, '4', 1),
#  (651, 'Equipment', 'Cat', 'small', '27.92', 1034.36, '6', 1),
#  (440, 'Toys', 'Cat', 'small', '34.47', 1374.79, '4', 0),
#  (654, 'Equipment', 'Fish', 'small', '22.98', 702.76, '5', 0),
#  (658, 'Housing', 'Dog', 'large', '35.92', 1182.28, '6', 1),
#  (659, 'Food', 'Cat', 'medium', '25.86', 826.9, '3', 1),
#  (660, 'Equipment', 'Cat', 'medium', '23.09', 792.03, '4', 1),
#  (661, 'Toys', 'Cat', 'small', '34.09', 1355.96, '8', 0),
#  (662, 'Housing', 'Fish', 'medium', '15.91', 369.09, '3', 0),
#  (663, 'Equipment', 'Cat', 'small', '28.02', 1033.6, '4', 0),
#  (664, 'Food', 'Dog', 'small', '36.07', 1133.67, '4', 0),
#  (480, 'Equipment', 'Fish', 'small', '23.09', 710.71, '6', 0),
#  (666, 'Food', 'Fish', 'small', '26.09', 732.64, '3', 0),
#  (667, 'Medicine', 'Cat', 'small', '24.92', 983.26, '3', 1),
#  (668, 'Accessory', 'Fish', 'small', '18.14', 451.79, '3', 1),
#  (669, 'Food', 'Dog', 'large', '40.83', 1456.02, '4', 1),
#  (671, 'Accessory', 'Fish', 'medium', '12.85', 286.94, '1', 1),
#  (672, 'Food', 'Cat', 'medium', '26.11', 836.46, '7', 0),
#  (673, 'Medicine', 'Fish', 'small', '19.78', 663.24, '6', 1),
#  (675, 'Housing', 'Fish', 'large', '25.94', 784.18, '4', 1),
#  (573, 'Medicine', 'Cat', 'medium', '19.94', 735.1, '7', 1),
#  (583, 'Housing', 'Cat', 'medium', '20.98', 616.62, '5', 1),
#  (596, 'Food', 'Cat', 'medium', '25.92', 828.76, '5', 1),
#  (630, 'Medicine', 'Fish', 'medium', '15.14', 467.23, '5', 1),
#  (670, 'Housing', 'Dog', 'medium', '26.06', 675.27, '4', 1),
#  (564, 'Toys', 'Fish', 'small', '29.25', 979.88, '5', 1),
#  (572, 'Toys', 'Cat', 'small', '34.23', 1359.67, '7', 1),
#  (581, 'Equipment', 'Cat', 'small', '28.13', 1035.27, '7', 1),
#  (688, 'Accessory', 'Cat', 'large', '28.29', 1009.17, '4', 0),
#  (693, 'Accessory', 'Bird', 'large', '43.13', 1422.67, '5', 1),
#  (728, 'Toys', 'Dog', 'large', '43.92', 1793.71, '6', 1),
#  (695, 'Toys', 'Fish', 'small', '28.93', 959.82, '6', 1),
#  (696, 'Food', 'Dog', 'small', '36.12', 1127.48, '5', 0),
#  (697, 'Equipment', 'Fish', 'small', '22.8', 700.69, '5', 1),
#  (698, 'Equipment', 'Fish', 'small', '22.89', 698.36, '4', 1),
#  (699, 'Food', 'Cat', 'large', '36.02', 1413.13, '7', 1),
#  (700, 'Housing', 'Dog', 'large', '36.21', 1196.63, '8', 1),
#  (701, 'Medicine', 'Dog', 'large', '34.93', 1430.7, '9', 0),
#  (702, 'Equipment', 'Fish', 'small', '23.02', 701.28, '3', 0),
#  (703, 'Equipment', 'Cat', 'medium', '22.84', 785.16, '4', 0),
#  (752, 'Food', 'Dog', 'large', '41.07', 1466.78, '6', 1),
#  (705, 'Medicine', 'Cat', 'small', '24.86', 979.63, '7', 1),
#  (706, 'Equipment', 'Cat', 'medium', '23.03', 795.76, '7', 0),
#  (708, 'Accessory', 'Cat', 'medium', '18.1', 516.87, '4', 1),
#  (754, 'Housing', 'Fish', 'large', '25.83', 776.93, '3', 1),
#  (712, 'Equipment', 'Cat', 'medium', '23.01', 791.79, '4', 0),
#  (713, 'Accessory', 'Fish', 'large', '22.99', 677.59, '4', 1),
#  (762, 'Medicine', 'Dog', 'large', '34.94', 1416.24, '9', 0),
#  (715, 'Medicine', 'Cat', 'small', '24.95', 981.83, '7', 0),
#  (716, 'Medicine', 'Cat', 'medium', '20.06', 741.31, '7', 0),
#  (718, 'Accessory', 'Cat', 'medium', '17.99', 514.68, '4', 1),
#  (719, 'Housing', 'Cat', 'small', '25.96', 828.28, '4', 0),
#  (721, 'Housing', 'Cat', 'medium', '20.83', 612.54, '4', 1),
#  (723, 'Medicine', 'Cat', 'large', '29.86', 1315.87, '7', 0),
#  (778, 'Food', 'Fish', 'large', '30.94', 1016.25, '3', 1),
#  (725, 'Equipment', 'Fish', 'medium', '18.22', 512.56, '2', 1),
#  (726, 'Housing', 'Cat', 'small', '25.96', 822.82, '4', 0),
#  (727, 'Toys', 'Fish', 'medium', '23.92', 741.3, '4', 1),
#  (729, 'Food', 'Bird', 'small', '45.98', 1450.78, '5', 0),
#  (784, 'Food', 'Dog', 'large', '41.02', 1464.26, '6', 0),
#  (731, 'Medicine', 'Dog', 'large', '34.95', 1414.51, '7', 0),
#  (732, 'Equipment', 'Cat', 'small', '28.03', 1027.94, '5', 0),
#  (733, 'Equipment', 'Dog', 'medium', '27.87', 862.21, '3', 1),
#  (734, 'Housing', 'Cat', 'small', '25.72', 811.65, '3', 1),
#  (735, '-', 'Cat', 'small', '25.03', 989.97, '6', 0),
#  (736, 'Medicine', 'Fish', 'small', '20.13', 668.35, '5', 0),
#  (737, 'Food', 'Fish', 'medium', '21.01', 546.78, '4', 0),
#  (485, 'Medicine', 'Bird', 'small', '39.79', 1476.14, '5', 1),
#  (739, 'Medicine', 'Dog', 'large', '35.09', 1423.65, '9', 0),
#  (740, 'Equipment', 'Fish', 'medium', '17.95', 508.24, '5', 1),
#  (742, 'Housing', 'Fish', 'medium', '16.1', 375.48, '4', 0),
#  (743, 'Housing', 'Dog', 'medium', '26.19', 678.2, '5', 0),
#  (487, 'Medicine', 'Cat', 'small', '24.74', 977.78, '7', 1),
#  (745, 'Food', 'Fish', 'large', '31', 1020.52, '6', 1),
#  (746, 'Housing', 'Fish', 'large', '26.07', 788.32, '4', 1),
#  (747, 'Toys', 'Cat', 'small', '34.05', 1351.58, '4', 1),
#  (489, 'Equipment', 'Fish', 'small', '23.07', 702.33, '5', 0),
#  (527, 'Equipment', 'Fish', 'small', '22.69', 695.63, '6', 1),
#  (755, 'Housing', 'Fish', 'medium', '16.02', 369.05, '2', 1),
#  (756, 'Food', 'Dog', 'small', '36.16', 1121.32, '4', 0),
#  (758, 'Toys', 'Fish', 'small', '28.86', 966.92, '4', 1),
#  (759, 'Equipment', 'Fish', 'large', '27.9', 982.61, '4', 1),
#  (760, 'Equipment', 'Dog', 'small', '32.85', 1107.57, '5', 1),
#  (761, 'Accessory', 'Fish', 'large', '23.09', 676.76, '4', 1),
#  (763, 'Toys', 'Cat', 'medium', '29', 1076.74, '7', 0),
#  (764, 'Food', 'Dog', 'medium', '30.87', 880.81, '3', 0),
#  (765, 'Toys', 'Fish', 'small', '29.26', 981.65, '6', 0),
#  (528, 'Medicine', 'Cat', 'small', '24.78', 975.55, '6', 1),
#  (767, 'Equipment', 'Cat', 'small', '27.78', 1020.3, '7', 1),
#  (768, 'Equipment', 'Cat', 'small', '27.71', 1019.84, '6', 1),
#  (769, 'Toys', 'Cat', 'large', '39.01', 1716.93, '8', 0),
#  (771, 'Food', 'Bird', 'small', '45.99', 1468.07, '3', 1),
#  (772, 'Medicine', 'Fish', 'small', '19.94', 664.58, '5', 1),
#  (774, 'Toys', 'Fish', 'medium', '24.02', 741.25, '5', 1),
#  (775, 'Equipment', 'Fish', 'small', '23.18', 705.78, '4', 0),
#  (776, 'Equipment', 'Fish', 'small', '22.7', 692.32, '5', 1),
#  (777, 'Accessory', 'Bird', 'large', '43.16', 1430.35, '6', 0),
#  (779, 'Food', 'Bird', 'medium', '41.1', 1205.54, '5', 0),
#  (780, 'Medicine', 'Fish', 'small', '19.94', 662.95, '7', 1),
#  (782, 'Accessory', 'Fish', 'medium', '13.13', 291.19, '1', 1),
#  (783, 'Accessory', 'Dog', 'medium', '23.02', 576.16, '4', 1),
#  (785, 'Medicine', 'Cat', 'medium', '20.13', 752.27, '6', 1),
#  (786, 'Accessory', 'Dog', 'large', '33.11', 1062.8, '7', 0),
#  (707, 'Equipment', 'Dog', 'medium', '27.98', 869.46, '5', 1),
#  (711, 'Accessory', 'Dog', 'medium', '22.96', 575.3, '3', 1),
#  (722, 'Housing', 'Cat', 'medium', '21.14', 618.85, '7', 1),
#  (750, 'Housing', 'Bird', 'medium', '35.95', 958.44, '2', 0),
#  (753, 'Toys', 'Fish', 'medium', '24.06', 747.21, '7', 1),
#  (773, 'Housing', 'Bird', 'medium', '35.95', 956.18, '5', 0),
#  (676, 'Toys', 'Dog', 'small', '39.07', 1413.09, '5', 0),
#  (680, 'Equipment', 'Cat', 'small', '28', 1037.85, '6', 0),
#  (690, 'Equipment', 'Cat', 'small', '27.91', 1029.62, '6', 1),
#  (710, 'Toys', 'Fish', 'small', '29.11', 973.54, '3', 0),
#  (717, 'Equipment', 'Cat', 'small', '27.88', 1034.76, '5', 1),
#  (720, 'Toys', 'Fish', 'small', '28.89', 962.99, '4', 1),
#  (810, 'Equipment', 'Dog', 'small', '33.04', 1109.25, '4', 0),
#  (812, 'Food', 'Bird', 'medium', '40.89', 1205.12, '3', 1),
#  (813, 'Housing', 'Fish', 'small', '20.92', 530.85, '4', 1),
#  (815, 'Medicine', 'Dog', 'medium', '24.88', 844.07, '4', 1),
#  (816, 'Medicine', 'Fish', 'large', '25.46', 960.09, '5', 1),
#  (817, 'Toys', 'Cat', 'small', '33.95', 1356.63, '6', 0),
#  (818, 'Food', 'Bird', 'small', '45.98', 1470.95, '4', 0),
#  (819, 'Equipment', 'Cat', 'small', '28.14', 1040.25, '7', 0),
#  (820, 'Medicine', 'Fish', 'small', '20.09', 668.82, '6', 1),
#  (821, 'Medicine', 'Dog', 'small', '29.95', 1086.46, '6', 1),
#  (823, 'Accessory', 'Cat', 'small', '23.13', 717.93, '6', 0),
#  (824, 'Medicine', 'Cat', 'small', '24.94', 980.93, '4', 0),
#  (825, 'Housing', 'Dog', 'small', '30.98', 876.43, '6', 1),
#  (826, 'Equipment', 'Cat', 'medium', '22.98', 790.28, '5', 1),
#  (828, 'Equipment', 'Cat', 'small', '28.36', 1041.38, '7', 0),
#  (829, 'Medicine', 'Cat', 'medium', '20.02', 745.34, '7', 0),
#  (830, 'Equipment', 'Cat', 'small', '28.02', 1034.11, '7', 1),
#  (831, 'Medicine', 'Cat', 'small', '24.91', 984.06, '6', 0),
#  (832, 'Medicine', 'Dog', 'medium', '24.85', 831.99, '3', 1),
#  (833, 'Toys', 'Cat', 'small', '33.88', 1349.47, '3', 1),
#  (834, 'Housing', 'Fish', 'small', '21.22', 544.35, '5', 1),
#  (837, 'Accessory', 'Bird', 'large', '42.99', 1415.63, '6', 0),
#  (838, 'Toys', 'Cat', 'small', '34.12', 1354.43, '7', 1),
#  (840, 'Equipment', 'Cat', 'small', '28.02', 1038.37, '5', 0),
#  (841, 'Food', 'Dog', 'medium', '30.97', 893.82, '4', 1),
#  (842, 'Equipment', 'Cat', 'small', '28.3', 1047.36, '4', 0),
#  (843, '-', 'Cat', 'small', '28.14', 1040.57, '7', 1),
#  (845, 'Housing', 'Dog', 'medium', '25.88', 675.98, '6', 1),
#  (846, 'Medicine', 'Fish', 'small', '20.07', 666.34, '3', 0),
#  (848, 'Food', 'Cat', 'small', '30.85', 1061.36, '4', 1),
#  (849, 'Accessory', 'Fish', 'large', '22.88', 671.44, '2', 1),
#  (851, 'Accessory', 'Bird', 'medium', '33.08', 857.2, '5', 1),
#  (852, 'Medicine', 'Dog', 'medium', '25.1', 842.65, '6', 1),
#  (853, 'Food', 'Bird', 'medium', '41', 1205.26, '5', 1),
#  (854, 'Medicine', 'Cat', 'medium', '19.93', 738.82, '8', 1),
#  (855, 'Equipment', 'Cat', 'small', '27.9', 1038.63, '5', 0),
#  (856, 'Housing', 'Cat', 'small', '25.86', 826.49, '1', 1),
#  (858, 'Accessory', 'Bird', 'large', '42.92', 1410.58, '5', 0),
#  (859, 'Equipment', 'Cat', 'small', '27.84', 1031.58, '4', 0),
#  (862, 'Equipment', 'Cat', 'small', '27.97', 1036.56, '3', 0),
#  (863, 'Toys', 'Cat', 'large', '38.99', 1724.15, '7', 1),
#  (864, 'Housing', 'Cat', 'medium', '21.21', 619.91, '4', 1),
#  (866, 'Housing', 'Cat', 'small', '26', 825.1, '6', 1),
#  (867, 'Toys', 'Cat', 'small', '33.86', 1335.86, '6', 0),
#  (868, 'Equipment', 'Cat', 'small', '28.13', 1037.69, '3', 1),
#  (869, 'Equipment', 'Cat', 'small', '27.74', 1022.85, '7', 0),
#  (871, 'Toys', 'Fish', 'small', '28.99', 979.7, '3', 1),
#  (873, 'Accessory', 'Fish', 'large', '23.12', 675.29, '6', 1),
#  (874, 'Housing', 'Fish', 'medium', '16.03', 371.78, '5', 0),
#  (865, 'Equipment', 'Dog', 'large', '37.87', 1441.13, '8', 0),
#  (876, 'Equipment', 'Fish', 'medium', '18.13', 511.4, '5', 1),
#  (877, 'Equipment', 'Cat', 'small', '28.04', 1038.43, '4', 1),
#  (878, 'Toys', 'Dog', 'small', '39.07', 1420.2, '6', 0),
#  (879, 'Food', 'Fish', 'medium', '20.95', 538.59, '2', 0),
#  (880, 'Toys', 'Cat', 'small', '33.97', 1354.37, '7', 1),
#  (881, 'Equipment', 'Fish', 'small', '22.98', 702.46, '6', 1),
#  (882, 'Housing', 'Fish', 'small', '21.21', 539.3, '2', 0),
#  (533, 'Equipment', 'Cat', 'small', '28.15', 1040.73, '8', 1),
#  (884, 'Equipment', 'Cat', 'small', '27.94', 1034.08, '5', 0),
#  (885, 'Toys', 'Cat', 'small', '34.07', 1342.9, '6', 0),
#  (534, 'Toys', 'Cat', 'small', '34.18', 1357.61, '7', 0),
#  (548, 'Food', 'Dog', 'small', '35.99', 1130.21, '3', 1),
#  (888, 'Equipment', 'Cat', 'small', '28.22', 1041.84, '6', 0),
#  (889, 'Medicine', 'Dog', 'small', '30.12', 1086.5, '3', 1),
#  (549, 'Toys', 'Bird', 'small', '49.02', 1820.0, '5', 1),
#  (891, 'Equipment', 'Cat', 'small', '27.9', 1032.07, '5', 1),
#  (892, 'Toys', 'Fish', 'large', '34.15', 1295.24, '7', 0),
#  (893, 'Equipment', 'Cat', 'small', '28.1', 1031.91, '4', 0),
#  (894, 'Medicine', 'Fish', 'large', '25.09', 946.65, '4', 1),
#  (597, 'Toys', 'Fish', 'small', '28.91', 975.67, '5', 0),
#  (896, 'Toys', 'Cat', 'small', '33.97', 1332.09, '7', 1),
#  (897, 'Housing', 'Fish', 'medium', '16.12', 374.75, '5', 1),
#  (898, 'Toys', 'Dog', 'medium', '34.07', 1157.99, '5', 0),
#  (793, 'Housing', 'Fish', 'medium', '16.12', 374.64, '3', 1),
#  (797, 'Food', 'Cat', 'medium', '25.98', 829.32, '7', 1),
#  (814, 'Housing', 'Bird', 'medium', '35.99', 965.29, '4', 1),
#  (836, 'Food', 'Dog', 'medium', '31', 886.74, '3', 1),
#  (839, 'Housing', 'Fish', 'medium', '16.16', 375.45, '4', 1),
#  (847, 'Medicine', 'Fish', 'medium', '14.89', 459.46, '4', 1),
#  (861, 'Food', 'Dog', 'medium', '31.14', 890.38, '3', 0),
#  (789, 'Equipment', 'Cat', 'small', '28.02', 1026.59, '5', 1),
#  (794, 'Equipment', 'Cat', 'small', '27.76', 1020.3, '6', 1),
#  (799, 'Equipment', 'Cat', 'small', '27.86', 1026.84, '5', 1),
#  (800, 'Toys', 'Cat', 'small', '34.02', 1355.03, '6', 1),
#  (927, 'Toys', 'Cat', 'small', '34.21', 1352.84, '7', 1),
#  (930, 'Medicine', 'Dog', 'medium', '24.83', 833.95, '4', 0),
#  (931, 'Toys', 'Cat', 'small', '34.18', 1363.79, '5', 1),
#  (932, 'Toys', 'Cat', 'small', '34.02', 1348.83, '9', 0),
#  (935, 'Housing', 'Fish', 'medium', '16.08', 373.2, '6', 1),
#  (936, 'Toys', 'Bird', 'medium', '43.97', 1522.17, '7', 0),
#  (937, 'Food', 'Fish', 'small', '25.83', 726.3, '5', 0),
#  (938, 'Equipment', 'Cat', 'small', '27.81', 1024.69, '4', 0),
#  (954, 'Accessory', 'Dog', 'large', '33.15', 1066.57, '6', 0),
#  (940, 'Food', 'Fish', 'medium', '21.02', 544.48, '4', 1),
#  (970, 'Food', 'Bird', 'large', '51.05', 1854.64, '5', 1),
#  (943, 'Housing', 'Fish', 'small', '21.21', 542.84, '3', 1),
#  (944, 'Food', 'Dog', 'small', '35.85', 1116.82, '5', 1),
#  (947, 'Toys', 'Cat', 'small', '33.92', 1341.72, '7', 0),
#  (949, 'Housing', 'Dog', 'medium', '25.91', 672.46, '5', 0),
#  (951, 'Medicine', 'Dog', 'medium', '25.05', 843.34, '6', 0),
#  (952, 'Equipment', 'Cat', 'small', '27.81', 1028.3, '5', 1),
#  (953, 'Toys', 'Cat', 'small', '34.04', 1346.22, '6', 1),
#  (955, 'Medicine', 'Fish', 'small', '20.26', 674.35, '6', 0),
#  (956, 'Food', 'Dog', 'medium', '30.82', 878.78, '3', 1),
#  (958, 'Housing', 'Cat', 'small', '26.02', 816.48, '6', 0),
#  (960, 'Medicine', 'Dog', 'small', '30.02', 1081.32, '3', 1),
#  (961, 'Housing', 'Cat', 'large', '30.85', 1118.18, '4', 0),
#  (962, 'Food', 'Dog', 'medium', '31.01', 894.05, '6', 1),
#  (963, '-', 'Cat', 'small', '25.06', 992.35, '7', 1),
#  (965, 'Accessory', 'Dog', 'large', '33', 1058.53, '6', 0),
#  (966, 'Toys', 'Dog', 'small', '39.07', 1415.91, '6', 0),
#  (967, 'Equipment', 'Cat', 'small', '28.06', 1036.52, '5', 1),
#  (968, 'Equipment', 'Cat', 'small', '27.95', 1027.25, '8', 1),
#  (969, 'Food', 'Fish', 'small', '25.96', 733.84, '6', 0),
#  (972, 'Equipment', 'Fish', 'small', '22.98', 707.54, '3', 1),
#  (973, 'Accessory', 'Dog', 'large', '32.99', 1059.35, '4', 1),
#  (974, 'Toys', 'Dog', 'medium', '34.06', 1150.23, '4', 1),
#  (975, 'Equipment', 'Cat', 'small', '28.25', 1040.92, '5', 0),
#  (976, 'Accessory', 'Bird', 'large', '43.01', 1418.55, '8', 1),
#  (981, 'Equipment', 'Cat', 'small', '27.74', 1019.89, '3', 1),
#  (982, 'Equipment', 'Cat', 'medium', '22.91', 787.99, '5', 1),
#  (987, 'Food', 'Dog', 'large', '41.03', 1460.01, '2', 1),
#  (984, 'Housing', 'Cat', 'medium', '21.1', 616.53, '5', 1),
#  (986, 'Medicine', 'Bird', 'medium', '35.07', 1202.57, '5', 0),
#  (988, 'Toys', 'Cat', 'small', '34.06', 1348.07, '8', 1),
#  (599, 'Equipment', 'Bird', 'small', '42.86', 1484.04, '5', 1),
#  (605, 'Equipment', 'Cat', 'small', '28.1', 1040.27, '6', 1),
#  (992, 'Toys', 'Fish', 'small', '28.82', 962.25, '8', 0),
#  (993, 'Toys', 'Cat', 'medium', '28.95', 1082.61, '7', 0),
#  (994, 'Equipment', 'Dog', 'medium', '28.24', 876.91, '4', 0),
#  (995, 'Equipment', 'Dog', 'small', '32.98', 1108.36, '7', 1),
#  (996, 'Toys', 'Fish', 'medium', '24.24', 752.56, '7', 1),
#  (997, 'Food', 'Dog', 'large', '40.81', 1452.83, '7', 1),
#  (999, 'Accessory', 'Bird', 'medium', '33', 857.71, '3', 0),
#  (607, 'Equipment', 'Cat', 'small', '27.98', 1026.38, '3', 0),
#  (1001, 'Food', 'Fish', 'medium', '20.87', 540.31, '4', 1),
#  (1003, 'Equipment', 'Cat', 'small', '28', 1027.35, '4', 1),
#  (608, 'Housing', 'Cat', 'small', '25.85', 814.58, '5', 1),
#  (1007, 'Equipment', 'Fish', 'small', '22.93', 710.63, '4', 1),
#  (899, 'Equipment', 'Cat', 'small', '28.08', 1034.93, '6', 0),
#  (1009, 'Housing', 'Dog', 'medium', '25.98', 670.61, '4', 1),
#  (1010, 'Toys', 'Cat', 'small', '34.07', 1347.5, '6', 1),
#  (909, 'Housing', 'Dog', 'medium', '26.01', 673.01, '4', 1),
#  (913, 'Food', 'Dog', 'medium', '31.11', 893.03, '6', 1),
#  (914, '-', 'Dog', 'medium', '34.07', 1148.89, '5', 1),
#  (933, 'Food', 'Bird', 'medium', '41.32', 1206.38, '4', 0),
#  (945, 'Toys', 'Fish', 'medium', '23.9', 741.42, '3', 1),
#  (964, 'Housing', 'Fish', 'medium', '16.19', 376.62, '1', 0),
#  (979, 'Housing', 'Bird', 'medium', '36.08', 959.73, '6', 1),
#  (998, 'Housing', 'Fish', 'medium', '16.07', 373.55, '4', 0),
#  (1004, 'Food', 'Dog', 'medium', '31.12', 889.96, '4', 0),
#  (1011, 'Medicine', 'Cat', 'medium', '20.02', 740.69, '6', 1),
#  (901, 'Food', 'Fish', 'small', '25.78', 722.29, '4', 0),
#  (902, 'Equipment', 'Cat', 'small', '28.03', 1029.89, '6', 0),
#  (903, 'Housing', 'Dog', 'small', '30.78', 873.15, '7', 1),
#  (908, 'Equipment', 'Cat', 'small', '28.2', 1043.24, '6', 0),
#  (915, 'Toys', 'Cat', 'small', '33.95', 1348.27, '7', 0),
#  (920, 'Equipment', 'Fish', 'small', '23.09', 706.5, '4', 1),
#  (1037, 'Food', 'Fish', 'small', '26.12', 740.36, '4', 1),
#  (1040, 'Equipment', 'Cat', 'small', '28.12', 1039.04, '4', 0),
#  (1041, 'Medicine', 'Fish', 'medium', '15.09', 463.31, '3', 1),
#  (1044, 'Medicine', 'Dog', 'medium', '25.07', 840.14, '6', 0),
#  (1045, 'Toys', 'Cat', 'small', '34.08', 1351.43, '8', 0),
#  (1047, 'Toys', 'Dog', 'small', '39.38', 1440.68, '8', 1),
#  (1048, 'Accessory', 'Dog', 'medium', '22.96', 578.3, '3', 1),
#  (1050, 'Equipment', 'Cat', 'large', '32.98', 1366.49, '7', 0),
#  (1084, 'Housing', 'Dog', 'large', '36.12', 1184.59, '6', 1),
#  (1052, 'Food', 'Fish', 'small', '26.16', 738.33, '6', 1),
#  (1053, 'Accessory', 'Bird', 'large', '42.92', 1418.79, '6', 0),
#  (1054, 'Housing', 'Fish', 'medium', '15.98', 375.68, '2', 0),
#  (1055, 'Food', 'Cat', 'medium', '26.15', 837.87, '5', 1),
#  (1088, 'Food', 'Fish', 'large', '31.03', 1018.51, '3', 1),
#  (1098, '-', 'Bird', 'large', '50.93', 1863.64, '5', 1),
#  (1061, 'Food', 'Dog', 'large', '41', 1463.58, '7', 1),
#  (1105, 'Toys', 'Bird', 'large', '54.07', 2244.67, '6', 1),
#  (1063, 'Housing', 'Cat', 'medium', '21.19', 621.37, '5', 1),
#  (1064, 'Accessory', 'Bird', 'large', '43.2', 1433.16, '4', 0),
#  (1065, 'Housing', 'Dog', 'medium', '25.97', 669.42, '5', 1),
#  (1066, 'Equipment', 'Cat', 'small', '28.09', 1036.27, '4', 1),
#  (1067, 'Equipment', 'Cat', 'small', '27.97', 1038.51, '4', 1),
#  (1068, 'Food', 'Fish', 'small', '26.02', 729.12, '6', 1),
#  (1069, 'Food', 'Bird', 'medium', '40.99', 1200.77, '3', 0),
#  (609, 'Toys', 'Fish', 'small', '28.79', 964.58, '6', 0),
#  (1071, 'Equipment', 'Cat', 'small', '28.18', 1034.92, '3', 1),
#  (616, 'Toys', 'Cat', 'small', '33.84', 1351.85, '6', 0),
#  (1074, 'Toys', 'Cat', 'small', '33.85', 1346.37, '6', 1),
#  (1075, 'Toys', 'Cat', 'medium', '28.96', 1073.72, '7', 1),
#  (1076, 'Toys', 'Fish', 'small', '28.88', 969.86, '5', 1),
#  (1077, 'Accessory', 'Bird', 'large', '43.05', 1419.46, '5', 1),
#  (646, 'Equipment', 'Cat', 'small', '27.85', 1031.22, '4', 1),
#  (1080, 'Food', 'Dog', 'medium', '30.95', 879.04, '3', 1),
#  (1081, 'Toys', 'Cat', 'small', '33.86', 1350.19, '8', 1),
#  (1082, 'Food', 'Dog', 'large', '40.99', 1460.03, '5', 0),
#  (1086, 'Food', 'Cat', 'medium', '26.09', 836.41, '3', 0),
#  (1087, 'Medicine', 'Fish', 'small', '19.87', 673.29, '6', 1),
#  (1089, 'Housing', 'Dog', 'medium', '26.1', 671.98, '5', 1),
#  (1090, 'Equipment', 'Dog', 'small', '32.84', 1107.49, '3', 0),
#  (1091, 'Toys', 'Cat', 'large', '38.99', 1723.84, '6', 0),
#  (1092, 'Medicine', 'Bird', 'medium', '34.96', 1199.48, '5', 0),
#  (1093, 'Housing', 'Dog', 'medium', '25.93', 669.59, '3', 1),
#  (1095, 'Toys', 'Cat', 'small', '33.94', 1351.92, '6', 1),
#  (1096, 'Food', 'Dog', 'medium', '31.03', 886.23, '6', 0),
#  (1099, 'Equipment', 'Fish', 'small', '23.1', 708.04, '4', 0),
#  (1100, '-', 'Cat', 'medium', '19.89', 737.02, '6', 1),
#  (1101, 'Food', 'Cat', 'medium', '26.03', 837.42, '3', 1),
#  (1102, 'Food', 'Cat', 'small', '30.82', 1061.82, '7', 0),
#  (1103, '-', 'Dog', 'small', '35.78', 1105.22, '3', 1),
#  (1104, 'Toys', 'Fish', 'small', '28.74', 956.72, '6', 1),
#  (1106, 'Medicine', 'Fish', 'medium', '15.06', 464.91, '5', 0),
#  (1107, 'Toys', 'Cat', 'small', '33.99', 1350.47, '6', 1),
#  (1108, 'Medicine', 'Dog', 'medium', '25.06', 839.05, '3', 0),
#  (1109, 'Accessory', 'Bird', 'medium', '33.01', 857.7, '5', 0),
#  (1110, 'Food', 'Dog', 'large', '40.85', 1456.65, '4', 0),
#  (1111, 'Equipment', 'Cat', 'medium', '22.83', 787.38, '5', 1),
#  (1113, 'Accessory', 'Bird', 'large', '42.82', 1415.63, '5', 0),
#  (1114, 'Food', 'Cat', 'large', '36.08', 1405.07, '4', 1),
#  (1115, 'Equipment', 'Cat', 'small', '27.97', 1028.23, '6', 1),
#  (1116, 'Toys', 'Cat', 'medium', '29.04', 1075.67, '7', 0),
#  (1117, 'Housing', 'Fish', 'medium', '16', 372.34, '3', 1),
#  (1119, 'Medicine', 'Fish', 'medium', '15.05', 466.99, '4', 1),
#  (1122, 'Medicine', 'Dog', 'small', '30.18', 1092.28, '3', 1),
#  (1123, 'Housing', 'Dog', 'medium', '25.97', 674.51, '1', 0),
#  (21, 'Food', 'Fish', 'medium', '0', 542.06, '0', 0),
#  (1026, 'Food', 'Dog', 'medium', '30.98', 886.47, '4', 1),
#  (1038, 'Toys', 'Dog', 'medium', '34.12', 1156.11, '6', 1),
#  (1043, 'Food', 'Cat', 'medium', '26.01', 837.5, '2', 1),
#  (1046, 'Accessory', 'Dog', 'medium', '22.81', 573.78, '3', 1),
#  (1112, 'Food', 'Fish', 'medium', '21.15', 546.52, '5', 1),
#  (1015, 'Housing', 'Fish', 'small', '20.91', 530.62, '5', 0),
#  (1019, 'Equipment', 'Cat', 'small', '28.17', 1034.85, '5', 1),
#  (1021, 'Housing', 'Cat', 'small', '26.33', 834.38, '3', 1),
#  (1022, 'Medicine', 'Fish', 'small', '20.15', 666.43, '4', 1),
#  (1139, 'Medicine', 'Fish', 'medium', '14.91', 461.45, '6', 1),
#  (1141, 'Equipment', 'Cat', 'medium', '22.99', 795.09, '6', 1),
#  (1144, 'Medicine', 'Dog', 'small', '30.12', 1090.12, '5', 1),
#  (1145, 'Toys', 'Cat', 'medium', '29.13', 1085.6, '8', 1),
#  (1142, 'Medicine', 'Dog', 'large', '34.89', 1422.11, '8', 1),
#  (1147, 'Toys', 'Dog', 'medium', '33.89', 1143.17, '5', 1),
#  (1143, 'Food', 'Dog', 'large', '40.94', 1457.65, '5', 1),
#  (1199, 'Food', 'Bird', 'large', '50.98', 1864.23, '6', 0),
#  (1151, 'Equipment', 'Dog', 'small', '33.19', 1120.87, '6', 1),
#  (1152, 'Food', 'Dog', 'medium', '30.98', 887.17, '5', 1),
#  (1153, 'Medicine', 'Dog', 'small', '29.93', 1074.88, '5', 1),
#  ...]

# %% [markdown]
# # highest sale for each animal

# %%
# %%sql
#
# select animal, max(sales) as highest_sales_for_bird
# from pet_supplies
# group by animal
# order by highest_sales_for_bird desc
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 4 rows affected.
# [('Bird', 2255.96), ('Dog', 1797.02), ('Cat', 1729.76), ('Fish', 1307.35)]

# %% [markdown]
# # total sales per animal

# %%
# %%sql
# select animal, sum(sales) as total_sales_per_animal
# from pet_supplies
# group by animal
# order by total_sales_per_animal desc
# limit 10
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 4 rows affected.
# [('Cat', 574232.4),
#  ('Dog', 388405.84),
#  ('Bird', 275000.0),
#  ('Fish', 257258.89)]

# %% [markdown]
# # how many repeated purchase

# %%
# %%sql
#
# select count(repeat_purchase) as Total_Number_Of_Repeated_Purchase, animal
# from pet_supplies
# where repeat_purchase = '1'
# group by animal
# order by  Total_Number_Of_Repeated_Purchase desc
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 4 rows affected.
# [(344, 'Cat'), (243, 'Fish'), (208, 'Dog'), (111, 'Bird')]

# %% [markdown]
# # the price of the most expensive food for fish

# %%
# %%sql
# select animal, category, max(price) as The_Most_Expensive_Fish_Food
# from pet_supplies
# where animal = 'Fish' and category = 'Food'
# group by animal, category
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 1 rows affected.
# [('Fish', 'Food', '31.16')]

# %% [markdown]
# # highest rating of each category

# %%
# %%sql
# select category, max(rating) as The_Highest_Per_Category
# from pet_supplies
# group by category
# order by The_Highest_Per_Category desc
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 7 rows affected.
# [('Equipment', '9'),
#  ('Medicine', '9'),
#  ('Toys', '9'),
#  ('Accessory', '8'),
#  ('-', '8'),
#  ('Food', '8'),
#  ('Housing', '8')]

# %% [markdown]
# # total sale for fish equipments

# %%
# %%sql
#
# select category, sum(sales) as The_Total_Sales_For_Fish_Equipment, animal
# from pet_supplies
# where animal = 'Fish' and category = 'Equipment'
# group by category, animal
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 1 rows affected.
# [('Equipment', 53399.797, 'Fish')]

# %% [markdown]
# # how many medium cat medicine were sold

# %%
# %%sql
#
# select animal, category, count(size) as Total_Number_Of_Medium_Sized_Cats_That_Were_Sold
# from pet_supplies
# where animal = 'Cat' and size = 'medium' and category = 'Medicine'
# group by animal, size, category
# Out:
#  * postgresql://postgres:***@localhost/sql_class
# 1 rows affected.
# [('Cat', 'Medicine', 27)]
